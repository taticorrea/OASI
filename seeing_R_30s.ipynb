# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from astropy.time import Time
import statistics as std
plt.style.use('classic')
# %matplotlib inline

# %%
it = ['2019-01-01T21:00:00']                             #Inicio das observaçoes
itime = Time(it, format = 'isot', scale = 'utc' )

# %% [markdown]
# <h1>ABRIL</h1>

# %% [markdown]
# <h2>2019-04-05</h2>

# %%
file = open('ABR/2019-04-05/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_5 = pd.read_csv('ABR/2019-04-05/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_5['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_5 = df_5[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_5['XBINNING']*df_5['FWHM']*df_5['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_5['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_5 = df_5[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_5
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-04-05T23:25:06      R      30.0  1.025579  1.8312         2  1.181833
# 1  2019-04-06T00:00:20      R      30.0  1.043149  1.8842         2  1.203707
# 2  2019-04-06T01:00:28      R      30.0  1.138096  1.9481         2  1.181152
# 3  2019-04-06T02:14:52      R      30.0  1.436551  2.8025         2  1.477593
# 4  2019-04-06T02:47:09      R      30.0  1.687509  2.5079         2  1.200506
#
#                   IMAGE-NAME
# 0  1998NU_30s_b2x2-001_R.fit
# 1  1998NU_30s_b2x2-035_R.fit
# 2  1998NU_30s_b2x2-136_R.fit
# 3  1998NU_30s_b2x2-154_R.fit
# 4  1998NU_30s_b2x2-201_R.fit

# %% [markdown]
# <h2>2019-04-07</h2>

# %%
file = open('ABR/2019-04-07/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_7 = pd.read_csv('ABR/2019-04-07/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_7['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_7 = df_7[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_7['XBINNING']*df_7['FWHM']*df_7['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_7['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_7 = df_7[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_7
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-04-08T00:32:04      R      30.0  1.081833  2.0309         2  1.269387
# 1  2019-04-08T01:00:07      R      30.0  1.138546  1.8805         2  1.139895
# 2  2019-04-08T02:00:12      R      30.0  1.357394  1.9982         2  1.089976
# 3  2019-04-08T03:07:51      R      30.0  1.212009  1.8278         2  1.067154
# 4  2019-04-08T04:00:11      R      30.0  1.473472  2.0957         2  1.088243
# 5  2019-04-08T04:36:16      R      30.0  1.795366  2.3524         2  1.084979
#
#                   IMAGE-NAME
# 0  1998NU_30s_b2x2-001_R.fit
# 1  1998NU_30s_b2x2-052_R.fit
# 2  1998NU_30s_b2x2-144_R.fit
# 3     666_30s_b2x2-001_R.fit
# 4     666_30s_b2x2-093_R.fit
# 5     666_30s_b2x2-122_R.fit

# %%
df_ABR = pd.concat([df_5,df_7],sort=False)
df_ABR.to_csv('seeing_30s_R_ABR.csv')
df_ABR
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-04-05T23:25:06      R      30.0  1.025579  1.8312         2  1.181833
# 1  2019-04-06T00:00:20      R      30.0  1.043149  1.8842         2  1.203707
# 2  2019-04-06T01:00:28      R      30.0  1.138096  1.9481         2  1.181152
# 3  2019-04-06T02:14:52      R      30.0  1.436551  2.8025         2  1.477593
# 4  2019-04-06T02:47:09      R      30.0  1.687509  2.5079         2  1.200506
# 0  2019-04-08T00:32:04      R      30.0  1.081833  2.0309         2  1.269387
# 1  2019-04-08T01:00:07      R      30.0  1.138546  1.8805         2  1.139895
# 2  2019-04-08T02:00:12      R      30.0  1.357394  1.9982         2  1.089976
# 3  2019-04-08T03:07:51      R      30.0  1.212009  1.8278         2  1.067154
# 4  2019-04-08T04:00:11      R      30.0  1.473472  2.0957         2  1.088243
# 5  2019-04-08T04:36:16      R      30.0  1.795366  2.3524         2  1.084979
#
#                   IMAGE-NAME
# 0  1998NU_30s_b2x2-001_R.fit
# 1  1998NU_30s_b2x2-035_R.fit
# 2  1998NU_30s_b2x2-136_R.fit
# 3  1998NU_30s_b2x2-154_R.fit
# 4  1998NU_30s_b2x2-201_R.fit
# 0  1998NU_30s_b2x2-001_R.fit
# 1  1998NU_30s_b2x2-052_R.fit
# 2  1998NU_30s_b2x2-144_R.fit
# 3     666_30s_b2x2-001_R.fit
# 4     666_30s_b2x2-093_R.fit
# 5     666_30s_b2x2-122_R.fit

# %% [markdown]
# <h1>JULHO</h1>

# %% [markdown]
# <h2>2019-07-05</h2>

# %%
file = open('JUL/2019-07-05/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_5 = pd.read_csv('JUL/2019-07-05/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
fwhm
# Out:
# [2.0381, 2.3415, 2.0484, 2.1283, 2.6701]

# %%
df_5['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm5
df_5 = df_5[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_5['XBINNING']*df_5['FWHM']*df_5['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_5['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_5 = df_5[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_5
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-07-05T22:23:56      R      30.0  1.020156  2.0381         2  1.319554
# 1  2019-07-05T23:00:14      R      30.0  1.057948  2.3415         2  1.483260
# 2  2019-07-06T00:00:19      R      30.0  1.193026  2.0484         2  1.207332
# 3  2019-07-06T01:00:29      R      30.0  1.478060  2.1283         2  1.103111
# 4  2019-07-06T01:51:32      R      30.0  1.980076  2.6701         2  1.161235
#
#                 IMAGE-NAME
# 0  1459_30s_b2x2-001_R.fit
# 1  1459_30s_b2x2-068_R.fit
# 2  1459_30s_b2x2-179_R.fit
# 3  1459_30s_b2x2-291_R.fit
# 4  1459_30s_b2x2-386_R.fit

# %%
df_JUL = df_5
df_JUL.to_csv('seeing_30s_R_JUL.csv')
df_JUL
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-07-05T22:23:56      R      30.0  1.020156  2.0381         2  1.319554
# 1  2019-07-05T23:00:14      R      30.0  1.057948  2.3415         2  1.483260
# 2  2019-07-06T00:00:19      R      30.0  1.193026  2.0484         2  1.207332
# 3  2019-07-06T01:00:29      R      30.0  1.478060  2.1283         2  1.103111
# 4  2019-07-06T01:51:32      R      30.0  1.980076  2.6701         2  1.161235
#
#                 IMAGE-NAME
# 0  1459_30s_b2x2-001_R.fit
# 1  1459_30s_b2x2-068_R.fit
# 2  1459_30s_b2x2-179_R.fit
# 3  1459_30s_b2x2-291_R.fit
# 4  1459_30s_b2x2-386_R.fit

# %% [markdown]
# <h1>AGOSTO</h1>

# %% [markdown]
# <h2>2019-08-23</h2>

# %%
file = open('AGO/2019-08-23/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_23 = pd.read_csv('AGO/2019-08-23/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_23['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_23 = df_23[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_23['XBINNING']*df_23['FWHM']*df_23['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_23['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_23 = df_23[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_23
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-24T02:25:51      R      30.0  1.042796  4.7403         1  1.514461
# 1  2019-08-24T03:25:48      R      30.0  1.108621  4.1282         1  1.271342
# 2  2019-08-24T04:04:08      R      30.0  1.113178  3.7538         1  1.153199
# 3  2019-08-24T05:01:18      R      30.0  1.212006  4.5479         1  1.327639
#
#                IMAGE-NAME
# 0  2014NW65_30s-001_R.fit
# 1  2014NW65_30s-023_R.fit
# 2  2017RG16_30s-001_R.fit
# 3  2013MZ11_30s-001_R.fit

# %% [markdown]
# <h2>2019-08-24</h2>

# %%
file = open('AGO/2019-08-24/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_24 = pd.read_csv('AGO/2019-08-24/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_24['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_24 = df_24[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_24['XBINNING']*df_24['FWHM']*df_24['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_24['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_24 = df_24[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_24
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-25T01:44:14      R      30.0  1.040795  3.7876         1  1.211482
# 1  2019-08-25T02:44:04      R      30.0  1.180095  3.5503         1  1.053142
# 2  2019-08-25T03:04:28      R      30.0  1.189666  4.3178         1  1.274616
# 3  2019-08-25T04:40:02      R      30.0  1.104070  3.4972         1  1.079678
# 4  2019-08-25T05:00:24      R      30.0  1.300382  3.5899         1  1.004642
# 5  2019-08-25T06:22:03      R      30.0  1.056585  3.3489         1  1.061528
# 6  2019-08-25T06:30:29      R      30.0  1.062784  3.3661         1  1.063241
#
#                IMAGE-NAME
# 0  2014NW65_30s-001_R.fit
# 1  1999LE31_30s-005_R.fit
# 2  2017RG16_30s-015_R.fit
# 3  2017RG16_30s-016_R.fit
# 4  2014LN28_30s-010_R.fit
# 5      7968_30s-016_R.fit
# 6      7968_30s-030_R.fit

# %% [markdown]
# <h2>2019-08-26</h2>

# %%
file = open('AGO/2019-08-26/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_26 = pd.read_csv('AGO/2019-08-26/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_26['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_26 = df_26[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_26['XBINNING']*df_26['FWHM']*df_26['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_26['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_26 = df_26[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_26
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-27T01:44:43      R      30.0  1.038572  5.9680         1  1.911343
# 1  2019-08-27T02:44:06      R      30.0  1.024290  5.4274         1  1.752709
# 2  2019-08-27T03:40:01      R      30.0  1.053469  4.3084         1  1.368090
#
#                     IMAGE-NAME
# 0  2014NW65_30s_b1x1-001_R.fit
# 1  2013QQ95_30s_b1x1-014_R.fit
# 2  2013MZ11_30s_b1x1-014_R.fit

# %%
df_AGO = pd.concat([df_23,df_24,df_26],sort=False)
df_AGO.to_csv('seeing_30s_R_AGO.csv')
df_AGO
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-24T02:25:51      R      30.0  1.042796  4.7403         1  1.514461
# 1  2019-08-24T03:25:48      R      30.0  1.108621  4.1282         1  1.271342
# 2  2019-08-24T04:04:08      R      30.0  1.113178  3.7538         1  1.153199
# 3  2019-08-24T05:01:18      R      30.0  1.212006  4.5479         1  1.327639
# 0  2019-08-25T01:44:14      R      30.0  1.040795  3.7876         1  1.211482
# 1  2019-08-25T02:44:04      R      30.0  1.180095  3.5503         1  1.053142
# 2  2019-08-25T03:04:28      R      30.0  1.189666  4.3178         1  1.274616
# 3  2019-08-25T04:40:02      R      30.0  1.104070  3.4972         1  1.079678
# 4  2019-08-25T05:00:24      R      30.0  1.300382  3.5899         1  1.004642
# 5  2019-08-25T06:22:03      R      30.0  1.056585  3.3489         1  1.061528
# 6  2019-08-25T06:30:29      R      30.0  1.062784  3.3661         1  1.063241
# 0  2019-08-27T01:44:43      R      30.0  1.038572  5.9680         1  1.911343
# 1  2019-08-27T02:44:06      R      30.0  1.024290  5.4274         1  1.752709
# 2  2019-08-27T03:40:01      R      30.0  1.053469  4.3084         1  1.368090
#
#                     IMAGE-NAME
# 0       2014NW65_30s-001_R.fit
# 1       2014NW65_30s-023_R.fit
# 2       2017RG16_30s-001_R.fit
# 3       2013MZ11_30s-001_R.fit
# 0       2014NW65_30s-001_R.fit
# 1       1999LE31_30s-005_R.fit
# 2       2017RG16_30s-015_R.fit
# 3       2017RG16_30s-016_R.fit
# 4       2014LN28_30s-010_R.fit
# 5           7968_30s-016_R.fit
# 6           7968_30s-030_R.fit
# 0  2014NW65_30s_b1x1-001_R.fit
# 1  2013QQ95_30s_b1x1-014_R.fit
# 2  2013MZ11_30s_b1x1-014_R.fit

# %% [markdown]
# <h1>SETEMBRO</h1>

# %% [markdown]
# <h2>2019-09-01</h2>

# %%
file = open('SET/2019-09-01/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_1 = pd.read_csv('SET/2019-09-01/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_1['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_1 = df_1[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_1['XBINNING']*df_1['FWHM']*df_1['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_1['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_1 = df_1[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_1
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-01T23:09:24      R      30.0  1.618163  2.6314         2  1.291741
# 1  2019-09-02T00:00:15      R      30.0  1.317284  2.3332         2  1.295824
#
#                     IMAGE-NAME
# 0  2001RB18_30s_b2x2-001_R.fit
# 1  2001RB18_30s_b2x2-096_R.fit

# %% [markdown]
# <h2>2019-09-02</h2>

# %%
file = open('SET/2019-09-02/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_2 = pd.read_csv('SET/2019-09-02/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_2['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_2 = df_2[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_2['XBINNING']*df_2['FWHM']*df_2['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_2['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_2 = df_2[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_2
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-03T04:21:25      R      30.0  1.215657  4.2224         1  1.230395
# 1  2019-09-03T05:00:43      R      30.0  1.539575  5.0002         1  1.264499
#
#            IMAGE-NAME
# 0  2013MZ11-001_R.fit
# 1  2004GN17-030_R.fit

# %% [markdown]
# <h2>2019-09-03</h2>

# %%
file = open('SET/2019-09-03/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_3 = pd.read_csv('SET/2019-09-03/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_3['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_3 = df_3[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_3['XBINNING']*df_3['FWHM']*df_3['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_3['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_3 = df_3[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_3
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-04T03:13:10      R      30.0  1.061997  3.3074         1  1.045164
# 1  2019-09-04T04:00:28      R      30.0  1.256301  3.1801         1  0.908566
#
#            IMAGE-NAME
# 0  2013MZ11-001_R.fit
# 1  2004GN17-025_R.fit

# %% [markdown]
# <h2>2019-09-22</h2>

# %%
file = open('SET/2019-09-22/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_22 = pd.read_csv('SET/2019-09-22/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_22['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_22 = df_22[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_22['XBINNING']*df_22['FWHM']*df_22['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_22['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_22 = df_22[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_22
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-23T03:32:08      R      30.0  1.538755  5.2105         1  1.318103
# 1  2019-09-23T04:00:27      R      30.0  1.247419  3.8637         1  1.108582
#
#                     IMAGE-NAME
# 0  2004GN17_30s_b1x1-001_R.fit
# 1  2013QQ95_30s_b1x1-012_R.fit

# %% [markdown]
# <h2>2019-09-24</h2>

# %%
file = open('SET/2019-09-24/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_24 = pd.read_csv('SET/2019-09-24/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_24['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_24 = df_24[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_24['XBINNING']*df_24['FWHM']*df_24['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_24['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_24 = df_24[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_24
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-25T03:25:27      R      30.0  1.360570  4.2130         1  1.147442
# 1  2019-09-25T04:00:21      R      30.0  1.259903  5.9037         1  1.683813
# 2  2019-09-25T04:47:48      R      30.0  1.152840  7.6926         1  2.314108
#
#                     IMAGE-NAME
# 0  2013MZ11_30s_b2x2-001_R.fit
# 1  1999LE31_30s_b2x2-010_R.fit
# 2      354P_30s_b2x2-015_R.fit

# %% [markdown]
# <h2>2019-09-25</h2>

# %%
file = open('SET/2019-09-25/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_25 = pd.read_csv('SET/2019-09-25/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_25['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_25 = df_25[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_25['XBINNING']*df_25['FWHM']*df_25['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_25['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_25 = df_25[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_25
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-26T03:14:42      R      30.0  1.146887  2.5729         2  1.552788
# 1  2019-09-26T03:41:46      R      30.0  1.147532  2.5441         2  1.534890
#
#                     IMAGE-NAME
# 0  2001RB18_30s_b2x2-001_R.fit
# 1  2001RB18_30s_b2x2-053_R.fit

# %%
df_SET = pd.concat([df_1,df_2,df_3,df_22,df_24,df_25],sort=False)
df_SET.to_csv('seeing_30s_R_SET.csv')
df_SET
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-01T23:09:24      R      30.0  1.618163  2.6314         2  1.291741
# 1  2019-09-02T00:00:15      R      30.0  1.317284  2.3332         2  1.295824
# 0  2019-09-03T04:21:25      R      30.0  1.215657  4.2224         1  1.230395
# 1  2019-09-03T05:00:43      R      30.0  1.539575  5.0002         1  1.264499
# 0  2019-09-04T03:13:10      R      30.0  1.061997  3.3074         1  1.045164
# 1  2019-09-04T04:00:28      R      30.0  1.256301  3.1801         1  0.908566
# 0  2019-09-23T03:32:08      R      30.0  1.538755  5.2105         1  1.318103
# 1  2019-09-23T04:00:27      R      30.0  1.247419  3.8637         1  1.108582
# 0  2019-09-25T03:25:27      R      30.0  1.360570  4.2130         1  1.147442
# 1  2019-09-25T04:00:21      R      30.0  1.259903  5.9037         1  1.683813
# 2  2019-09-25T04:47:48      R      30.0  1.152840  7.6926         1  2.314108
# 0  2019-09-26T03:14:42      R      30.0  1.146887  2.5729         2  1.552788
# 1  2019-09-26T03:41:46      R      30.0  1.147532  2.5441         2  1.534890
#
#                     IMAGE-NAME
# 0  2001RB18_30s_b2x2-001_R.fit
# 1  2001RB18_30s_b2x2-096_R.fit
# 0           2013MZ11-001_R.fit
# 1           2004GN17-030_R.fit
# 0           2013MZ11-001_R.fit
# 1           2004GN17-025_R.fit
# 0  2004GN17_30s_b1x1-001_R.fit
# 1  2013QQ95_30s_b1x1-012_R.fit
# 0  2013MZ11_30s_b2x2-001_R.fit
# 1  1999LE31_30s_b2x2-010_R.fit
# 2      354P_30s_b2x2-015_R.fit
# 0  2001RB18_30s_b2x2-001_R.fit
# 1  2001RB18_30s_b2x2-053_R.fit

# %% [markdown]
# <h1>OUTUBRO</h1>

# %% [markdown]
# <h2>2019-10-28</h2>

# %%
file = open('OUT/2019-10-28/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_28 = pd.read_csv('OUT/2019-10-28/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_28['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_28 = df_28[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_28['XBINNING']*df_28['FWHM']*df_28['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_28['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_28 = df_28[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_28
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-10-29T00:47:05      R      30.0  1.038298  4.1802         1  1.338985
# 1  2019-10-29T01:05:26      R      30.0  1.067363  4.5261         1  1.425965
# 2  2019-10-29T02:10:19      R      30.0  1.053676  3.9241         1  1.245912
# 3  2019-10-29T03:00:32      R      30.0  1.158958  4.8722         1  1.461020
# 4  2019-10-29T03:33:39      R      30.0  1.131641  6.2844         1  1.911659
#
#                              IMAGE-NAME
# 0       Gonzalo_2060_30s_b1x1-001_R.fit
# 1      Gonzalo_30512_30s_b1x1-001_R.fit
# 2  Gonzalo_2014OG392_30s_b1x1-001_R.fit
# 3  Gonzalo_2014OG392_30s_b1x1-029_R.fit
# 4     Gonzalo_464762_30s_b1x1-015_R.fit

# %%
df_OUT = df_25
df_OUT.to_csv('seeing_30s_R_OUT.csv')
df_OUT
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-26T03:14:42      R      30.0  1.146887  2.5729         2  1.552788
# 1  2019-09-26T03:41:46      R      30.0  1.147532  2.5441         2  1.534890
#
#                     IMAGE-NAME
# 0  2001RB18_30s_b2x2-001_R.fit
# 1  2001RB18_30s_b2x2-053_R.fit

# %% [markdown]
# <h1>NOVEMBRO</h1>

# %% [markdown]
# <h2>2019-11-04</h2>

# %%
file = open('NOV/2019-11-04/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_4 = pd.read_csv('NOV/2019-11-04/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_4['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_4 = df_4[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_4['XBINNING']*df_4['FWHM']*df_4['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_4['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_4 = df_4[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_4
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-11-04T23:09:53      R      30.0  1.105767  3.2501         1  1.002467
# 1  2019-11-05T00:50:50      R      30.0  1.217828  4.7026         1  1.368857
# 2  2019-11-05T01:02:54      R      30.0  1.346441  4.8443         1  1.327671
# 3  2019-11-05T02:38:45      R      30.0  1.075845  4.6636         1  1.462323
# 4  2019-11-05T03:02:27      R      30.0  1.127384  4.0583         1  1.237294
# 5  2019-11-05T03:31:25      R      30.0  1.414324  5.2252         1  1.390418
#
#                      IMAGE-NAME
# 0        1999LE31_30s-001_R.fit
# 1        2017RG16_30s-001_R.fit
# 2        1999LE31_30s-016_R.fit
# 3   2011AT15_30s_b2x2-001_R.fit
# 4   2011AT15_30s_b2x2-016_R.fit
# 5  2014OG392_30s_b2x2-030_R.fit

# %% [markdown]
# <h2>2019-11-20</h2>

# %%
file = open('NOV/2019-11-20/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_20 = pd.read_csv('NOV/2019-11-20/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_20['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_20 = df_20[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_20['XBINNING']*df_20['FWHM']*df_20['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_20['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_20 = df_20[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_20
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-11-21T01:48:29      R      30.0  1.081773  5.2505         1  1.640933
# 1  2019-11-21T02:38:14      R      30.0  1.093514  5.3210         1  1.652230
# 2  2019-11-21T03:11:52      R      30.0  1.337204  4.8753         1  1.341697
# 3  2019-11-21T03:32:22      R      30.0  1.187440  5.3188         1  1.571877
#
#                          IMAGE-NAME
# 0  Gonz_2000KD41_b1x1_30s-001_R.fit
# 1       2014QA43_b1x1_30s-001_R.fit
# 2  Gonz_2000KD41_b1x1_30s-016_R.fit
# 3  Gonz_2014QA43_b1x1_30s-015_R.fit

# %% [markdown]
# <h2>2019-11-21</h2>

# %%
file = open('NOV/2019-11-21/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_21 = pd.read_csv('NOV/2019-11-21/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_21['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_21 = df_21[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_21['XBINNING']*df_21['FWHM']*df_21['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_21['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_21 = df_21[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_21
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-11-22T03:08:52      R      30.0  1.293527  4.9675         1  1.394583
# 1  2019-11-22T04:23:35      R      30.0  1.424431  4.2403         1  1.123527
# 2  2019-11-22T04:31:14      R      30.0  1.449436  4.7943         1  1.257122
#
#                              IMAGE-NAME
# 0          2015PN291_b1x1_30s-001_R.fit
# 1  Gonzalo_2015PN291_b1x1_30s-001_R.fit
# 2  Gonzalo_2015PN291_b1x1_30s-015_R.fit

# %% [markdown]
# <h2>2019-11-23</h2>

# %%
file = open('NOV/2019-11-23/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_23 = pd.read_csv('NOV/2019-11-23/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_23['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_23 = df_23[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_23['XBINNING']*df_23['FWHM']*df_23['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_23['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_23 = df_23[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_23
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-11-24T02:52:36      R      30.0  1.225117  3.9978         1  1.159542
# 1  2019-11-24T04:03:10      R      30.0  1.429694  4.8915         1  1.293207
# 2  2019-11-24T05:07:24      R      30.0  1.838425  4.4937         1  1.021665
# 3  2019-11-24T05:38:45      R      30.0  1.903235  4.8618         1  1.082613
#
#                         IMAGE-NAME
# 0    Gonzalo_1984WE1_30s-015_R.fit
# 1  Gonzalo_2005TS100_30s-002_R.fit
# 2  Gonzalo_2005TS100_30s-016_R.fit
# 3  Gonzalo_2015PN291_30s-030_R.fit

# %% [markdown]
# <h2>2019-11-30</h2>

# %%
file = open('NOV/2019-11-30/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_30 = pd.read_csv('NOV/2019-11-30/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_30['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_30 = df_30[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_30['XBINNING']*df_30['FWHM']*df_30['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_30['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_30 = df_30[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_30
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-11-30T22:24:24      R      30.0  1.059542  5.0576         1  1.600462
# 1  2019-11-30T23:00:20      R      30.0  1.045958  5.6856         1  1.813174
# 2  2019-12-01T00:40:21      R      30.0  1.047916  7.6636         1  2.441231
# 3  2019-12-01T00:48:02      R      30.0  1.056611  9.1125         1  2.888419
#
#                             IMAGE-NAME
# 0   Gonzalo_1994EQ3_30s_b1x1-001_R.fit
# 1  Gonzalo_2000KD41_30s_b1x1-008_R.fit
# 2  Gonzalo_2000KD41_30s_b1x1-016_R.fit
# 3  Gonzalo_2000KD41_30s_b1x1-030_R.fit

# %%
df_NOV = pd.concat([df_4,df_20,df_21,df_23,df_30],sort=False)
df_NOV.to_csv('seeing_30s_R_NOV.csv')
df_NOV
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-11-04T23:09:53      R      30.0  1.105767  3.2501         1  1.002467
# 1  2019-11-05T00:50:50      R      30.0  1.217828  4.7026         1  1.368857
# 2  2019-11-05T01:02:54      R      30.0  1.346441  4.8443         1  1.327671
# 3  2019-11-05T02:38:45      R      30.0  1.075845  4.6636         1  1.462323
# 4  2019-11-05T03:02:27      R      30.0  1.127384  4.0583         1  1.237294
# 5  2019-11-05T03:31:25      R      30.0  1.414324  5.2252         1  1.390418
# 0  2019-11-21T01:48:29      R      30.0  1.081773  5.2505         1  1.640933
# 1  2019-11-21T02:38:14      R      30.0  1.093514  5.3210         1  1.652230
# 2  2019-11-21T03:11:52      R      30.0  1.337204  4.8753         1  1.341697
# 3  2019-11-21T03:32:22      R      30.0  1.187440  5.3188         1  1.571877
# 0  2019-11-22T03:08:52      R      30.0  1.293527  4.9675         1  1.394583
# 1  2019-11-22T04:23:35      R      30.0  1.424431  4.2403         1  1.123527
# 2  2019-11-22T04:31:14      R      30.0  1.449436  4.7943         1  1.257122
# 0  2019-11-24T02:52:36      R      30.0  1.225117  3.9978         1  1.159542
# 1  2019-11-24T04:03:10      R      30.0  1.429694  4.8915         1  1.293207
# 2  2019-11-24T05:07:24      R      30.0  1.838425  4.4937         1  1.021665
# 3  2019-11-24T05:38:45      R      30.0  1.903235  4.8618         1  1.082613
# 0  2019-11-30T22:24:24      R      30.0  1.059542  5.0576         1  1.600462
# 1  2019-11-30T23:00:20      R      30.0  1.045958  5.6856         1  1.813174
# 2  2019-12-01T00:40:21      R      30.0  1.047916  7.6636         1  2.441231
# 3  2019-12-01T00:48:02      R      30.0  1.056611  9.1125         1  2.888419
#
#                              IMAGE-NAME
# 0                1999LE31_30s-001_R.fit
# 1                2017RG16_30s-001_R.fit
# 2                1999LE31_30s-016_R.fit
# 3           2011AT15_30s_b2x2-001_R.fit
# 4           2011AT15_30s_b2x2-016_R.fit
# 5          2014OG392_30s_b2x2-030_R.fit
# 0      Gonz_2000KD41_b1x1_30s-001_R.fit
# 1           2014QA43_b1x1_30s-001_R.fit
# 2      Gonz_2000KD41_b1x1_30s-016_R.fit
# 3      Gonz_2014QA43_b1x1_30s-015_R.fit
# 0          2015PN291_b1x1_30s-001_R.fit
# 1  Gonzalo_2015PN291_b1x1_30s-001_R.fit
# 2  Gonzalo_2015PN291_b1x1_30s-015_R.fit
# 0         Gonzalo_1984WE1_30s-015_R.fit
# 1       Gonzalo_2005TS100_30s-002_R.fit
# 2       Gonzalo_2005TS100_30s-016_R.fit
# 3       Gonzalo_2015PN291_30s-030_R.fit
# 0    Gonzalo_1994EQ3_30s_b1x1-001_R.fit
# 1   Gonzalo_2000KD41_30s_b1x1-008_R.fit
# 2   Gonzalo_2000KD41_30s_b1x1-016_R.fit
# 3   Gonzalo_2000KD41_30s_b1x1-030_R.fit

# %% [markdown]
# <h1>DEZEMBRO</h1>

# %% [markdown]
# <h2>2019-12-02</h2>

# %%
file = open('DEZ/2019-12-02/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_2 = pd.read_csv('DEZ/2019-12-02/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_2['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_2 = df_2[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_2['XBINNING']*df_2['FWHM']*df_2['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_2['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_2 = df_2[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_2
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS     FWHM  XBINNING  \
# 0  2019-12-02T22:32:22      R      30.0  1.019324   9.7257         1
# 1  2019-12-02T23:00:11      R      30.0  1.050878  11.2277         1
# 2  2019-12-03T00:42:55      R      30.0  1.073569   9.7313         1
# 3  2019-12-03T00:50:34      R      30.0  1.088032  10.2164         1
#
#      SEEING                     IMAGE-NAME
# 0  3.149963  G_2014OG92_30s_b1x1-001_R.fit
# 1  3.570518   G_1999OX3_30s_b1x1-011_R.fit
# 2  3.055235  G_2014OG92_30s_b1x1-016_R.fit
# 3  3.181887  G_2014OG92_30s_b1x1-030_R.fit

# %% [markdown]
# <h2>2019-12-03</h2>

# %%
file = open('DEZ/2019-12-03/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_3 = pd.read_csv('DEZ/2019-12-03/hselect_30s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_3['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_3 = df_3[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_3['XBINNING']*df_3['FWHM']*df_3['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_3['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_3 = df_3[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_3
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-12-03T22:50:36      R      30.0  1.043907  5.4979         1  1.755382
# 1  2019-12-03T22:58:17      R      30.0  1.037253  4.7483         1  1.521875
# 2  2019-12-04T00:44:17      R      30.0  1.068165  6.8799         1  2.166561
# 3  2019-12-04T00:51:57      R      30.0  1.079786  6.9319         1  2.168809
#
#                       IMAGE-NAME
# 0  G_2000KD41_30s_b1x1-001_R.fit
# 1  G_2000KD41_30s_b1x1-015_R.fit
# 2   G2000KD41_30s_b1x1-001_R.fit
# 3   G2000KD41_30s_b1x1-015_R.fit

# %%
df_DEZ = pd.concat([df_2,df_3],sort=False)
df_DEZ.to_csv('seeing_30s_R_DEZ.csv')
df_DEZ
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS     FWHM  XBINNING  \
# 0  2019-12-02T22:32:22      R      30.0  1.019324   9.7257         1
# 1  2019-12-02T23:00:11      R      30.0  1.050878  11.2277         1
# 2  2019-12-03T00:42:55      R      30.0  1.073569   9.7313         1
# 3  2019-12-03T00:50:34      R      30.0  1.088032  10.2164         1
# 0  2019-12-03T22:50:36      R      30.0  1.043907   5.4979         1
# 1  2019-12-03T22:58:17      R      30.0  1.037253   4.7483         1
# 2  2019-12-04T00:44:17      R      30.0  1.068165   6.8799         1
# 3  2019-12-04T00:51:57      R      30.0  1.079786   6.9319         1
#
#      SEEING                     IMAGE-NAME
# 0  3.149963  G_2014OG92_30s_b1x1-001_R.fit
# 1  3.570518   G_1999OX3_30s_b1x1-011_R.fit
# 2  3.055235  G_2014OG92_30s_b1x1-016_R.fit
# 3  3.181887  G_2014OG92_30s_b1x1-030_R.fit
# 0  1.755382  G_2000KD41_30s_b1x1-001_R.fit
# 1  1.521875  G_2000KD41_30s_b1x1-015_R.fit
# 2  2.166561   G2000KD41_30s_b1x1-001_R.fit
# 3  2.168809   G2000KD41_30s_b1x1-015_R.fit

# %%
df = pd.concat([df_ABR,df_AGO,df_DEZ,df_JUL,df_NOV,df_OUT,df_SET],sort=False)
df.to_csv('seeing_30s.csv')
df
# Out:
#                DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING  \
# 0   2019-04-05T23:25:06      R      30.0  1.025579  1.8312         2
# 1   2019-04-06T00:00:20      R      30.0  1.043149  1.8842         2
# 2   2019-04-06T01:00:28      R      30.0  1.138096  1.9481         2
# 3   2019-04-06T02:14:52      R      30.0  1.436551  2.8025         2
# 4   2019-04-06T02:47:09      R      30.0  1.687509  2.5079         2
# ..                  ...    ...       ...       ...     ...       ...
# 0   2019-09-25T03:25:27      R      30.0  1.360570  4.2130         1
# 1   2019-09-25T04:00:21      R      30.0  1.259903  5.9037         1
# 2   2019-09-25T04:47:48      R      30.0  1.152840  7.6926         1
# 0   2019-09-26T03:14:42      R      30.0  1.146887  2.5729         2
# 1   2019-09-26T03:41:46      R      30.0  1.147532  2.5441         2
#
#       SEEING                   IMAGE-NAME
# 0   1.181833    1998NU_30s_b2x2-001_R.fit
# 1   1.203707    1998NU_30s_b2x2-035_R.fit
# 2   1.181152    1998NU_30s_b2x2-136_R.fit
# 3   1.477593    1998NU_30s_b2x2-154_R.fit
# 4   1.200506    1998NU_30s_b2x2-201_R.fit
# ..       ...                          ...
# 0   1.147442  2013MZ11_30s_b2x2-001_R.fit
# 1   1.683813  1999LE31_30s_b2x2-010_R.fit
# 2   2.314108      354P_30s_b2x2-015_R.fit
# 0   1.552788  2001RB18_30s_b2x2-001_R.fit
# 1   1.534890  2001RB18_30s_b2x2-053_R.fit
#
# [74 rows x 8 columns]

# %% [markdown]
# <h1>Seeing x Tempo </h1>

# %%
lista_tempos = Time(list(df['DATE-OBS']),format='isot',scale='utc')

dt = []
t = np.empty(len(df['DATE-OBS']))

for i in range(len(lista_tempos)):
    dt.append(lista_tempos[i] - itime)
    t[i] = (dt[i].value)/30

# %%
estat = pd.DataFrame({'MÉDIA':[std.mean(df['SEEING'])],'MEDIANA':[std.median(df['SEEING'])],'MODA':[''],'DESVPAD':[std.stdev(df['SEEING'])]})
estat.to_csv('estat_R_30s.dat')
estat
# Out:
#       MÉDIA   MEDIANA MODA   DESVPAD
# 0  1.482854  1.294516       0.553525

# %%
'''
Modas calculadas com o comando std.multimode() no pyhton3.8, rodado no terminal
'''

plt.figure(figsize=(9,7))
plt.hist(list(df['SEEING']),bins = 45,label = 'Filtro R\n Tempo de exposição = 30s',color = 'darkorange',alpha = 0.5,lw = 1,edgecolor = 'black')
plt.ylabel('Frquência das imagens',size = 15)
plt.xlabel('Seeing (")',size = 15)
plt.xticks(np.arange(0,5,0.5),size = 15)
plt.yticks(np.arange(0,13,2),size = 15)
#plt.title('Seeing (1.48 $\pm$ 0.55) arcsec' + '      mediana 1.29 arcsec',size = 12,color='black')
plt.title('Média = 1.48 arcsec      Mediana = 1.29 arcsec      Moda = 1.35 arcsec      $\sigma$ = 0.55 arcsec',size = 10)
plt.legend(prop={'size': 10},frameon = True,loc = 'upper right', fancybox = True, framealpha = 1, shadow = True, borderpad = 0.5 )
plt.savefig('seeing_30s.png')
plt.show()

# %%
seeing_15 = df[(df.SEEING < 1.5)]
seeing_15
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-04-05T23:25:06      R      30.0  1.025579  1.8312         2  1.181833
# 1  2019-04-06T00:00:20      R      30.0  1.043149  1.8842         2  1.203707
# 2  2019-04-06T01:00:28      R      30.0  1.138096  1.9481         2  1.181152
# 3  2019-04-06T02:14:52      R      30.0  1.436551  2.8025         2  1.477593
# 4  2019-04-06T02:47:09      R      30.0  1.687509  2.5079         2  1.200506
# 0  2019-04-08T00:32:04      R      30.0  1.081833  2.0309         2  1.269387
# 1  2019-04-08T01:00:07      R      30.0  1.138546  1.8805         2  1.139895
# 2  2019-04-08T02:00:12      R      30.0  1.357394  1.9982         2  1.089976
# 3  2019-04-08T03:07:51      R      30.0  1.212009  1.8278         2  1.067154
# 4  2019-04-08T04:00:11      R      30.0  1.473472  2.0957         2  1.088243
# 5  2019-04-08T04:36:16      R      30.0  1.795366  2.3524         2  1.084979
# 1  2019-08-24T03:25:48      R      30.0  1.108621  4.1282         1  1.271342
# 2  2019-08-24T04:04:08      R      30.0  1.113178  3.7538         1  1.153199
# 3  2019-08-24T05:01:18      R      30.0  1.212006  4.5479         1  1.327639
# 0  2019-08-25T01:44:14      R      30.0  1.040795  3.7876         1  1.211482
# 1  2019-08-25T02:44:04      R      30.0  1.180095  3.5503         1  1.053142
# 2  2019-08-25T03:04:28      R      30.0  1.189666  4.3178         1  1.274616
# 3  2019-08-25T04:40:02      R      30.0  1.104070  3.4972         1  1.079678
# 4  2019-08-25T05:00:24      R      30.0  1.300382  3.5899         1  1.004642
# 5  2019-08-25T06:22:03      R      30.0  1.056585  3.3489         1  1.061528
# 6  2019-08-25T06:30:29      R      30.0  1.062784  3.3661         1  1.063241
# 2  2019-08-27T03:40:01      R      30.0  1.053469  4.3084         1  1.368090
# 0  2019-07-05T22:23:56      R      30.0  1.020156  2.0381         2  1.319554
# 1  2019-07-05T23:00:14      R      30.0  1.057948  2.3415         2  1.483260
# 2  2019-07-06T00:00:19      R      30.0  1.193026  2.0484         2  1.207332
# 3  2019-07-06T01:00:29      R      30.0  1.478060  2.1283         2  1.103111
# 4  2019-07-06T01:51:32      R      30.0  1.980076  2.6701         2  1.161235
# 0  2019-11-04T23:09:53      R      30.0  1.105767  3.2501         1  1.002467
# 1  2019-11-05T00:50:50      R      30.0  1.217828  4.7026         1  1.368857
# 2  2019-11-05T01:02:54      R      30.0  1.346441  4.8443         1  1.327671
# 3  2019-11-05T02:38:45      R      30.0  1.075845  4.6636         1  1.462323
# 4  2019-11-05T03:02:27      R      30.0  1.127384  4.0583         1  1.237294
# 5  2019-11-05T03:31:25      R      30.0  1.414324  5.2252         1  1.390418
# 2  2019-11-21T03:11:52      R      30.0  1.337204  4.8753         1  1.341697
# 0  2019-11-22T03:08:52      R      30.0  1.293527  4.9675         1  1.394583
# 1  2019-11-22T04:23:35      R      30.0  1.424431  4.2403         1  1.123527
# 2  2019-11-22T04:31:14      R      30.0  1.449436  4.7943         1  1.257122
# 0  2019-11-24T02:52:36      R      30.0  1.225117  3.9978         1  1.159542
# 1  2019-11-24T04:03:10      R      30.0  1.429694  4.8915         1  1.293207
# 2  2019-11-24T05:07:24      R      30.0  1.838425  4.4937         1  1.021665
# 3  2019-11-24T05:38:45      R      30.0  1.903235  4.8618         1  1.082613
# 0  2019-09-01T23:09:24      R      30.0  1.618163  2.6314         2  1.291741
# 1  2019-09-02T00:00:15      R      30.0  1.317284  2.3332         2  1.295824
# 0  2019-09-03T04:21:25      R      30.0  1.215657  4.2224         1  1.230395
# 1  2019-09-03T05:00:43      R      30.0  1.539575  5.0002         1  1.264499
# 0  2019-09-04T03:13:10      R      30.0  1.061997  3.3074         1  1.045164
# 1  2019-09-04T04:00:28      R      30.0  1.256301  3.1801         1  0.908566
# 0  2019-09-23T03:32:08      R      30.0  1.538755  5.2105         1  1.318103
# 1  2019-09-23T04:00:27      R      30.0  1.247419  3.8637         1  1.108582
# 0  2019-09-25T03:25:27      R      30.0  1.360570  4.2130         1  1.147442
#
#                              IMAGE-NAME
# 0             1998NU_30s_b2x2-001_R.fit
# 1             1998NU_30s_b2x2-035_R.fit
# 2             1998NU_30s_b2x2-136_R.fit
# 3             1998NU_30s_b2x2-154_R.fit
# 4             1998NU_30s_b2x2-201_R.fit
# 0             1998NU_30s_b2x2-001_R.fit
# 1             1998NU_30s_b2x2-052_R.fit
# 2             1998NU_30s_b2x2-144_R.fit
# 3                666_30s_b2x2-001_R.fit
# 4                666_30s_b2x2-093_R.fit
# 5                666_30s_b2x2-122_R.fit
# 1                2014NW65_30s-023_R.fit
# 2                2017RG16_30s-001_R.fit
# 3                2013MZ11_30s-001_R.fit
# 0                2014NW65_30s-001_R.fit
# 1                1999LE31_30s-005_R.fit
# 2                2017RG16_30s-015_R.fit
# 3                2017RG16_30s-016_R.fit
# 4                2014LN28_30s-010_R.fit
# 5                    7968_30s-016_R.fit
# 6                    7968_30s-030_R.fit
# 2           2013MZ11_30s_b1x1-014_R.fit
# 0               1459_30s_b2x2-001_R.fit
# 1               1459_30s_b2x2-068_R.fit
# 2               1459_30s_b2x2-179_R.fit
# 3               1459_30s_b2x2-291_R.fit
# 4               1459_30s_b2x2-386_R.fit
# 0                1999LE31_30s-001_R.fit
# 1                2017RG16_30s-001_R.fit
# 2                1999LE31_30s-016_R.fit
# 3           2011AT15_30s_b2x2-001_R.fit
# 4           2011AT15_30s_b2x2-016_R.fit
# 5          2014OG392_30s_b2x2-030_R.fit
# 2      Gonz_2000KD41_b1x1_30s-016_R.fit
# 0          2015PN291_b1x1_30s-001_R.fit
# 1  Gonzalo_2015PN291_b1x1_30s-001_R.fit
# 2  Gonzalo_2015PN291_b1x1_30s-015_R.fit
# 0         Gonzalo_1984WE1_30s-015_R.fit
# 1       Gonzalo_2005TS100_30s-002_R.fit
# 2       Gonzalo_2005TS100_30s-016_R.fit
# 3       Gonzalo_2015PN291_30s-030_R.fit
# 0           2001RB18_30s_b2x2-001_R.fit
# 1           2001RB18_30s_b2x2-096_R.fit
# 0                    2013MZ11-001_R.fit
# 1                    2004GN17-030_R.fit
# 0                    2013MZ11-001_R.fit
# 1                    2004GN17-025_R.fit
# 0           2004GN17_30s_b1x1-001_R.fit
# 1           2013QQ95_30s_b1x1-012_R.fit
# 0           2013MZ11_30s_b2x2-001_R.fit

# %%
len(seeing_15)
# Out:
# 50

# %%
it = ['2019-01-01T21:00:00']                             #Inicio das observaçoes
itime = Time(it, format = 'isot', scale = 'utc' )

# %%
lista_tempos = Time(list(seeing_15['DATE-OBS']),format='isot',scale='utc')

dt = []
t = np.empty(len(seeing_15['DATE-OBS']))

for i in range(len(lista_tempos)):
    dt.append(lista_tempos[i] - itime)
    t[i] = (dt[i].value)/30

# %%
t
# Out:
# array([ 3.13669213,  3.13750772,  3.13889969,  3.14062191,  3.14136921,
#         3.20490895,  3.20555826,  3.20694907,  3.20851505,  3.20972647,
#         3.21056173,  7.80893056,  7.8098179 ,  7.8111412 ,  7.83991281,
#         7.84129784,  7.84177006,  7.84398225,  7.8444537 ,  7.84634375,
#         7.84653897,  7.90925965,  6.16860957,  6.16944985,  6.17084066,
#         6.17223341,  6.17341512, 10.23633989, 10.2386767 , 10.23895602,
#        10.24117477, 10.24172338, 10.2423939 , 10.77527469, 10.80853858,
#        10.81026813, 10.81044522, 10.8748287 , 10.87646219, 10.87794907,
#        10.87867477,  8.10299537,  8.10417245,  8.14355131,  8.14446103,
#         8.17530478,  8.17639969,  8.80907716,  8.80973264,  8.87558912])

# %%
plt.figure(figsize=(9,7))
plt.scatter(t,seeing_15['SEEING'], label = 'Filtro R\nTempo de exposição = 30s', color = 'darkorange', alpha = 1,lw = 0.8,edgecolor = 'black')
plt.xticks(np.arange(13),('Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez'), rotation = 45, size = 15)
plt.yticks(np.arange(1,2,0.5))
plt.xlabel('Tempo de observação',size = 15)
plt.ylabel('Seeing (")',size = 15)
plt.legend(prop={'size': 10},frameon = True,loc = 'upper right', fancybox = True, framealpha = 1, shadow = True, borderpad = 0.5 )
plt.savefig('seeingxtempo_30s.png')
plt.show()
