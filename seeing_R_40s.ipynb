# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from astropy.time import Time
plt.style.use('classic')
import statistics as std
# %matplotlib inline

# %%
it = ['2019-01-01T21:00:00']                             #Inicio das observaçoes
itime = Time(it, format = 'isot', scale = 'utc' )

# %% [markdown]
# <h1>JANEIRO</h1>

# %% [markdown]
# <h2>2019-01-08</h2>

# %%
file = open('JAN/2019-01-08/logfile2','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_8 = pd.read_csv('JAN/2019-01-08/hselect_R_40s.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
len(fwhm)
# Out:
# 9

# %%
df_8['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_8 = df_8[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_8['XBINNING']*df_8['FWHM']*df_8['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_8['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_8 = df_8[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_8
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-01-08T23:11:50      R      40.0  2.436941  1.9656         2  0.754727
# 1  2019-01-09T00:00:41      R      40.0  1.769175  1.8695         2  0.869891
# 2  2019-01-09T01:00:31      R      40.0  1.396026  2.1602         2  1.158670
# 3  2019-01-09T02:00:28      R      40.0  1.226796  1.9850         2  1.150532
# 4  2019-01-09T03:00:21      R      40.0  1.170334  1.7584         2  1.048416
# 5  2019-01-09T04:00:25      R      40.0  1.202557  1.7153         2  1.006187
# 6  2019-01-09T05:00:14      R      40.0  1.336387  1.9304         2  1.062893
# 7  2019-01-09T06:00:31      R      40.0  1.641643  2.3700         2  1.153408
# 8  2019-01-09T06:20:18      R      40.0  1.808434  2.3712         2  1.088901
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-070_R.fit
# 2  1998NU_40s_b2x2-155_R.fit
# 3  1998NU_40s_b2x2-240_R.fit
# 4  1998NU_40s_b2x2-324_R.fit
# 5  1998NU_40s_b2x2-408_R.fit
# 6  1998NU_40s_b2x2-473_R.fit
# 7  1998NU_40s_b2x2-537_R.fit
# 8  1998NU_40s_b2x2-565_R.fit

# %% [markdown]
# <h2>2019-01-10</h2>

# %%
file = open('JAN/2019-01-10/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 279 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_10 = pd.read_csv('JAN/2019-01-10/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_10['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_10 = df_10[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_10['XBINNING']*df_10['FWHM']*df_10['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_10['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_10 = df_10[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_10
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-01-10T23:59:03      R      40.0  1.706065  1.8906         2  0.899092
# 1  2019-01-11T01:00:32      R      40.0  1.360031  1.8001         2  0.980775
# 2  2019-01-11T02:00:18      R      40.0  1.210659  2.1919         2  1.280588
# 3  2019-01-11T03:00:05      R      40.0  1.167013  1.8485         2  1.104017
# 4  2019-01-11T04:00:26      R      40.0  1.211813  1.6537         2  0.965600
# 5  2019-01-11T04:49:14      R      40.0  1.324878  1.6419         2  0.908747
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-088_R.fit
# 2  1998NU_40s_b2x2-166_R.fit
# 3  1998NU_40s_b2x2-192_R.fit
# 4  1998NU_40s_b2x2-275_R.fit
# 5  1998NU_40s_b2x2-333_R.fit

# %% [markdown]
# <h2>2019-01-12</h2>

# %%
file = open('JAN/2019-01-12/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_12 = pd.read_csv('JAN/2019-01-12/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
fwhm
# Out:
# [1.8559, 2.4137, 2.4246, 2.8683, 2.5487]

# %%
df_12['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_12 = df_12[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_12['XBINNING']*df_12['FWHM']*df_12['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_12['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_12 = df_12[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_12
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-01-13T01:02:33      R      40.0  1.320953  1.8559         2  1.029020
# 1  2019-01-13T04:10:22      R      40.0  1.242063  2.4137         2  1.388669
# 2  2019-01-13T05:00:32      R      40.0  1.394088  2.4246         2  1.301571
# 3  2019-01-13T06:00:04      R      40.0  1.767688  2.8683         2  1.335313
# 4  2019-01-13T06:31:35      R      40.0  2.137089  2.5487         2  1.058832
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-010_R.fit
# 2  1998NU_40s_b2x2-080_R.fit
# 3  1998NU_40s_b2x2-163_R.fit
# 4  1998NU_40s_b2x2-207_R.fit

# %% [markdown]
# <h2>2019-01-13</h2>

# %%
file = open('JAN/2019-01-13/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_13 = pd.read_csv('JAN/2019-01-13/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_13['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_13 = df_13[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_13['XBINNING']*df_13['FWHM']*df_13['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_13['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_13 = df_13[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_13
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-01-14T02:03:16      R      40.0  1.186181  3.1330         2  1.852984
# 1  2019-01-14T03:04:40      R      40.0  1.166164  5.6694         2  3.387530
# 2  2019-01-14T05:12:48      R      40.0  1.464193  6.0216         2  3.138735
# 3  2019-01-14T05:53:33      R      40.0  1.737343  5.8801         2  2.766019
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-057_R.fit
# 2  1998NU_40s_b2x2-065_R.fit
# 3  1998NU_40s_b2x2-099_R.fit

# %%
df_JAN = pd.concat([df_8, df_10, df_12, df_13],sort=False)
df_JAN.to_csv('seeing_40s_R_JAN.csv')
df_JAN
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-01-08T23:11:50      R      40.0  2.436941  1.9656         2  0.754727
# 1  2019-01-09T00:00:41      R      40.0  1.769175  1.8695         2  0.869891
# 2  2019-01-09T01:00:31      R      40.0  1.396026  2.1602         2  1.158670
# 3  2019-01-09T02:00:28      R      40.0  1.226796  1.9850         2  1.150532
# 4  2019-01-09T03:00:21      R      40.0  1.170334  1.7584         2  1.048416
# 5  2019-01-09T04:00:25      R      40.0  1.202557  1.7153         2  1.006187
# 6  2019-01-09T05:00:14      R      40.0  1.336387  1.9304         2  1.062893
# 7  2019-01-09T06:00:31      R      40.0  1.641643  2.3700         2  1.153408
# 8  2019-01-09T06:20:18      R      40.0  1.808434  2.3712         2  1.088901
# 0  2019-01-10T23:59:03      R      40.0  1.706065  1.8906         2  0.899092
# 1  2019-01-11T01:00:32      R      40.0  1.360031  1.8001         2  0.980775
# 2  2019-01-11T02:00:18      R      40.0  1.210659  2.1919         2  1.280588
# 3  2019-01-11T03:00:05      R      40.0  1.167013  1.8485         2  1.104017
# 4  2019-01-11T04:00:26      R      40.0  1.211813  1.6537         2  0.965600
# 5  2019-01-11T04:49:14      R      40.0  1.324878  1.6419         2  0.908747
# 0  2019-01-13T01:02:33      R      40.0  1.320953  1.8559         2  1.029020
# 1  2019-01-13T04:10:22      R      40.0  1.242063  2.4137         2  1.388669
# 2  2019-01-13T05:00:32      R      40.0  1.394088  2.4246         2  1.301571
# 3  2019-01-13T06:00:04      R      40.0  1.767688  2.8683         2  1.335313
# 4  2019-01-13T06:31:35      R      40.0  2.137089  2.5487         2  1.058832
# 0  2019-01-14T02:03:16      R      40.0  1.186181  3.1330         2  1.852984
# 1  2019-01-14T03:04:40      R      40.0  1.166164  5.6694         2  3.387530
# 2  2019-01-14T05:12:48      R      40.0  1.464193  6.0216         2  3.138735
# 3  2019-01-14T05:53:33      R      40.0  1.737343  5.8801         2  2.766019
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-070_R.fit
# 2  1998NU_40s_b2x2-155_R.fit
# 3  1998NU_40s_b2x2-240_R.fit
# 4  1998NU_40s_b2x2-324_R.fit
# 5  1998NU_40s_b2x2-408_R.fit
# 6  1998NU_40s_b2x2-473_R.fit
# 7  1998NU_40s_b2x2-537_R.fit
# 8  1998NU_40s_b2x2-565_R.fit
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-088_R.fit
# 2  1998NU_40s_b2x2-166_R.fit
# 3  1998NU_40s_b2x2-192_R.fit
# 4  1998NU_40s_b2x2-275_R.fit
# 5  1998NU_40s_b2x2-333_R.fit
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-010_R.fit
# 2  1998NU_40s_b2x2-080_R.fit
# 3  1998NU_40s_b2x2-163_R.fit
# 4  1998NU_40s_b2x2-207_R.fit
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-057_R.fit
# 2  1998NU_40s_b2x2-065_R.fit
# 3  1998NU_40s_b2x2-099_R.fit

# %% [markdown]
# <h1>FEVEREIRO</h1>

# %% [markdown]
# <h2>2019-02-27</h2>

# %%
file = open('FEV/2019-02-27/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_27 = pd.read_csv('FEV/2019-02-27/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_27['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_27 = df_27[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_27['XBINNING']*df_27['FWHM']*df_27['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_27['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_27 = df_27[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_27
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-02-27T22:58:47      R      40.0  1.130387  2.1482         2  1.307797
# 1  2019-02-27T23:51:44      R      40.0  1.082804  2.0457         2  1.277950
# 2  2019-02-28T00:54:54      R      40.0  1.107063  2.2601         2  1.393241
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-032_R.fit
# 2  1998NU_40s_b2x2-051_R.fit

# %% [markdown]
# <h2>2019-02-28</h2>

# %%
file = open('FEV/2019-02-28/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_28 = pd.read_csv('FEV/2019-02-28/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_28['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_28 = df_28[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_28['XBINNING']*df_28['FWHM']*df_28['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_28['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_28 = df_28[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_28
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-02-28T23:40:58      R      40.0  1.084230  2.8469         2  1.777056
# 1  2019-03-01T02:01:11      R      40.0  1.245768  2.2671         2  1.301998
# 2  2019-03-01T03:11:56      R      40.0  1.612969  2.5716         2  1.264822
# 3  2019-03-01T04:01:40      R      40.0  2.206756  3.3010         2  1.345224
# 4  2019-03-01T06:28:07      R      40.0  2.173260  2.1621         2  0.889223
#
#                    IMAGE-NAME
# 0   1998NU_40s_b2x2-001_R.fit
# 1   1998NU_40s_b2x2-034_R.fit
# 2   1998NU_40s_b2x2-043_R.fit
# 3   1998NU_40s_b2x2-072_R.fit
# 4  2019CT4_40s_b2x2-085_R.fit

# %%
df_FEV = pd.concat([df_27,df_28],sort=False)
df_FEV.to_csv('seeing_40s_R_FEV.csv')
df_FEV
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-02-27T22:58:47      R      40.0  1.130387  2.1482         2  1.307797
# 1  2019-02-27T23:51:44      R      40.0  1.082804  2.0457         2  1.277950
# 2  2019-02-28T00:54:54      R      40.0  1.107063  2.2601         2  1.393241
# 0  2019-02-28T23:40:58      R      40.0  1.084230  2.8469         2  1.777056
# 1  2019-03-01T02:01:11      R      40.0  1.245768  2.2671         2  1.301998
# 2  2019-03-01T03:11:56      R      40.0  1.612969  2.5716         2  1.264822
# 3  2019-03-01T04:01:40      R      40.0  2.206756  3.3010         2  1.345224
# 4  2019-03-01T06:28:07      R      40.0  2.173260  2.1621         2  0.889223
#
#                    IMAGE-NAME
# 0   1998NU_40s_b2x2-001_R.fit
# 1   1998NU_40s_b2x2-032_R.fit
# 2   1998NU_40s_b2x2-051_R.fit
# 0   1998NU_40s_b2x2-001_R.fit
# 1   1998NU_40s_b2x2-034_R.fit
# 2   1998NU_40s_b2x2-043_R.fit
# 3   1998NU_40s_b2x2-072_R.fit
# 4  2019CT4_40s_b2x2-085_R.fit

# %% [markdown]
# <h1>MARÇO</h1>

# %% [markdown]
# <h2>2019-03-01</h2>

# %%
file = open('MAR/2019-03-01/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_1 = pd.read_csv('MAR/2019-03-01/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_1['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_1 = df_1[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_1['XBINNING']*df_1['FWHM']*df_1['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_1['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_1 = df_1[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_1
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-03-01T22:46:58      R      40.0  1.138540  2.1745         2  1.318112
# 1  2019-03-02T00:00:40      R      40.0  1.077030  2.1708         2  1.360457
# 2  2019-03-02T01:20:10      R      40.0  1.146555  1.8409         2  1.111207
# 3  2019-03-02T02:01:18      R      40.0  1.250701  2.1941         2  1.257089
# 4  2019-03-02T03:00:17      R      40.0  1.053168  2.1161         2  1.344124
#
#                    IMAGE-NAME
# 0   1998NU_40s_b2x2-001_R.fit
# 1   1998NU_40s_b2x2-044_R.fit
# 2   1998NU_40s_b2x2-054_R.fit
# 3   1998NU_40s_b2x2-078_R.fit
# 4  2019CT4_40s_b2x2-022_R.fit

# %% [markdown]
# <h2>2019-03-02</h2>

# %%
file = open('MAR/2019-03-02/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_2 = pd.read_csv('MAR/2019-03-02/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_2['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_2 = df_2[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_2['XBINNING']*df_2['FWHM']*df_2['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_2['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_2 = df_2[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_2
# Out:
#               DATE-OBS FILTER  EXP-TIME  AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-03-03T00:04:51      R      40.0  1.18444  4.1323         2  2.446165
#
#                    IMAGE-NAME
# 0  2019CT4_40s_b2x2-006_R.fit

# %% [markdown]
# <h2>2019-03-08</h2>

# %%
file = open('MAR/2019-03-08/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_8 = pd.read_csv('MAR/2019-03-08/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_8['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_8 = df_8[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_8['XBINNING']*df_8['FWHM']*df_8['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_8['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_8 = df_8[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_8
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-03-09T02:33:16      R      40.0  1.431091  1.9146         2  1.011765
# 1  2019-03-09T03:00:24      R      40.0  1.617732  1.8339         2  0.900396
# 2  2019-03-09T04:00:32      R      40.0  2.442613  2.2336         2  0.856435
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-040_R.fit
# 2  1998NU_40s_b2x2-126_R.fit

# %% [markdown]
# <h2>2019-03-29</h2>

# %%
file = open('MAR/2019-03-29/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_29 = pd.read_csv('MAR/2019-03-29/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_29['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_29 = df_29[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_29['XBINNING']*df_29['FWHM']*df_29['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_29['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_29 = df_29[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_29
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-03-29T22:14:19      R      40.0  1.082722  2.1216         2  1.325425
# 1  2019-03-29T23:00:21      R      40.0  1.038372  1.6351         2  1.047453
# 2  2019-03-30T00:00:04      R      40.0  1.046619  1.5185         2  0.968152
# 3  2019-03-30T01:00:02      R      40.0  1.134060  1.6576         2  1.007163
# 4  2019-03-30T02:00:15      R      40.0  1.338562  1.7026         2  0.936551
# 5  2019-03-30T03:00:20      R      40.0  1.785438  1.9504         2  0.902565
# 6  2019-03-30T04:00:40      R      40.0  1.252640  1.9111         2  1.093930
# 7  2019-03-30T05:00:08      R      40.0  1.613141  2.2792         2  1.120936
# 8  2019-03-30T05:42:30      R      40.0  2.139813  2.0041         2  0.831947
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-064_R.fit
# 2  1998NU_40s_b2x2-140_R.fit
# 3  1998NU_40s_b2x2-223_R.fit
# 4  1998NU_40s_b2x2-295_R.fit
# 5  1998NU_40s_b2x2-380_R.fit
# 6     666_40s_b2x2-026_R.fit
# 7     666_40s_b2x2-102_R.fit
# 8     666_40s_b2x2-142_R.fit

# %% [markdown]
# <h2>2019-03-31</h2>

# %%
file = open('MAR/2019-03-31/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_31 = pd.read_csv('MAR/2019-03-31/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_31['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_31 = df_31[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_31['XBINNING']*df_31['FWHM']*df_31['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_31['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_31 = df_31[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_31
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-03-31T23:47:27      R      40.0  1.037063  1.5498         2  0.993561
# 1  2019-04-01T00:00:07      R      40.0  1.045245  1.4149         2  0.902810
# 2  2019-04-01T01:01:42      R      40.0  1.138426  1.4448         2  0.875844
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-019_R.fit
# 2  1998NU_40s_b2x2-076_R.fit

# %%
df_MAR = pd.concat([df_1,df_2,df_8,df_29,df_31],sort=False)
df_MAR.to_csv('seeing_40s_R_MAR.csv')
df_MAR
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-03-01T22:46:58      R      40.0  1.138540  2.1745         2  1.318112
# 1  2019-03-02T00:00:40      R      40.0  1.077030  2.1708         2  1.360457
# 2  2019-03-02T01:20:10      R      40.0  1.146555  1.8409         2  1.111207
# 3  2019-03-02T02:01:18      R      40.0  1.250701  2.1941         2  1.257089
# 4  2019-03-02T03:00:17      R      40.0  1.053168  2.1161         2  1.344124
# 0  2019-03-03T00:04:51      R      40.0  1.184440  4.1323         2  2.446165
# 0  2019-03-09T02:33:16      R      40.0  1.431091  1.9146         2  1.011765
# 1  2019-03-09T03:00:24      R      40.0  1.617732  1.8339         2  0.900396
# 2  2019-03-09T04:00:32      R      40.0  2.442613  2.2336         2  0.856435
# 0  2019-03-29T22:14:19      R      40.0  1.082722  2.1216         2  1.325425
# 1  2019-03-29T23:00:21      R      40.0  1.038372  1.6351         2  1.047453
# 2  2019-03-30T00:00:04      R      40.0  1.046619  1.5185         2  0.968152
# 3  2019-03-30T01:00:02      R      40.0  1.134060  1.6576         2  1.007163
# 4  2019-03-30T02:00:15      R      40.0  1.338562  1.7026         2  0.936551
# 5  2019-03-30T03:00:20      R      40.0  1.785438  1.9504         2  0.902565
# 6  2019-03-30T04:00:40      R      40.0  1.252640  1.9111         2  1.093930
# 7  2019-03-30T05:00:08      R      40.0  1.613141  2.2792         2  1.120936
# 8  2019-03-30T05:42:30      R      40.0  2.139813  2.0041         2  0.831947
# 0  2019-03-31T23:47:27      R      40.0  1.037063  1.5498         2  0.993561
# 1  2019-04-01T00:00:07      R      40.0  1.045245  1.4149         2  0.902810
# 2  2019-04-01T01:01:42      R      40.0  1.138426  1.4448         2  0.875844
#
#                    IMAGE-NAME
# 0   1998NU_40s_b2x2-001_R.fit
# 1   1998NU_40s_b2x2-044_R.fit
# 2   1998NU_40s_b2x2-054_R.fit
# 3   1998NU_40s_b2x2-078_R.fit
# 4  2019CT4_40s_b2x2-022_R.fit
# 0  2019CT4_40s_b2x2-006_R.fit
# 0   1998NU_40s_b2x2-001_R.fit
# 1   1998NU_40s_b2x2-040_R.fit
# 2   1998NU_40s_b2x2-126_R.fit
# 0   1998NU_40s_b2x2-001_R.fit
# 1   1998NU_40s_b2x2-064_R.fit
# 2   1998NU_40s_b2x2-140_R.fit
# 3   1998NU_40s_b2x2-223_R.fit
# 4   1998NU_40s_b2x2-295_R.fit
# 5   1998NU_40s_b2x2-380_R.fit
# 6      666_40s_b2x2-026_R.fit
# 7      666_40s_b2x2-102_R.fit
# 8      666_40s_b2x2-142_R.fit
# 0   1998NU_40s_b2x2-001_R.fit
# 1   1998NU_40s_b2x2-019_R.fit
# 2   1998NU_40s_b2x2-076_R.fit

# %% [markdown]
# <h1>ABRIL</h1>

# %% [markdown]
# <h2>2019-04-02</h2>

# %%
file = open('ABR/2019-04-02/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_2 = pd.read_csv('ABR/2019-04-02/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_2['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_2 = df_2[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_2['XBINNING']*df_2['FWHM']*df_2['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_2['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_2 = df_2[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_2
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-04-02T23:55:27      R      40.0  1.040799  2.4181         2  1.546878
# 1  2019-04-03T00:00:28      R      40.0  1.044654  3.0461         2  1.944296
# 2  2019-04-03T01:00:03      R      40.0  1.135837  3.1894         2  1.936070
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-008_R.fit
# 2  1998NU_40s_b2x2-083_R.fit

# %% [markdown]
# <h2>2019-04-03</h2>

# %%
file = open('ABR/2019-04-03/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_3 = pd.read_csv('ABR/2019-04-03/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_3['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_3 = df_3[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_3['XBINNING']*df_3['FWHM']*df_3['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_3['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_3 = df_3[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_3
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-04-04T01:19:29      R      40.0  1.191480  2.2971         2  1.354970
# 1  2019-04-04T02:00:22      R      40.0  1.355549  2.4023         2  1.311475
# 2  2019-04-04T02:19:45      R      40.0  1.468386  2.3201         2  1.207270
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-058_R.fit
# 2  1998NU_40s_b2x2-085_R.fit

# %% [markdown]
# <h2>2019-04-04</h2>

# %%
file = open('ABR/2019-04-04/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_4 = pd.read_csv('ABR/2019-04-04/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_4['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_4 = df_4[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_4['XBINNING']*df_4['FWHM']*df_4['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_4['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_4 = df_4[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_4
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING   SEEING  \
# 0  2019-04-05T02:39:59      R      40.0  1.616248  3.1326         2  1.53887
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit

# %% [markdown]
# <h2>2019-04-11</h2>

# %%
file = open('ABR/2019-04-11/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_11 = pd.read_csv('ABR/2019-04-11/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_11['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_11 = df_11[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_11['XBINNING']*df_11['FWHM']*df_11['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_11['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_11 = df_11[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_11
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-04-12T00:33:20      R      40.0  1.084968  4.4423         2  2.771784
# 1  2019-04-12T03:28:34      R      40.0  2.317221  3.5952         2  1.422802
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-012_R.fit

# %%
df_ABR = pd.concat([df_2,df_3,df_4,df_11],sort=False)
df_ABR.to_csv('seeing_40s_R_ABR.csv')
df_ABR
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-04-02T23:55:27      R      40.0  1.040799  2.4181         2  1.546878
# 1  2019-04-03T00:00:28      R      40.0  1.044654  3.0461         2  1.944296
# 2  2019-04-03T01:00:03      R      40.0  1.135837  3.1894         2  1.936070
# 0  2019-04-04T01:19:29      R      40.0  1.191480  2.2971         2  1.354970
# 1  2019-04-04T02:00:22      R      40.0  1.355549  2.4023         2  1.311475
# 2  2019-04-04T02:19:45      R      40.0  1.468386  2.3201         2  1.207270
# 0  2019-04-05T02:39:59      R      40.0  1.616248  3.1326         2  1.538870
# 0  2019-04-12T00:33:20      R      40.0  1.084968  4.4423         2  2.771784
# 1  2019-04-12T03:28:34      R      40.0  2.317221  3.5952         2  1.422802
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-008_R.fit
# 2  1998NU_40s_b2x2-083_R.fit
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-058_R.fit
# 2  1998NU_40s_b2x2-085_R.fit
# 0  1998NU_40s_b2x2-001_R.fit
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-012_R.fit

# %% [markdown]
# <h1>MAIO</h1>

# %% [markdown]
# <h2>2019-05-01</h2>

# %%
file = open('MAI/2019-05-01/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_1 = pd.read_csv('MAI/2019-05-01/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_1['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_1 = df_1[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_1['XBINNING']*df_1['FWHM']*df_1['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_1['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_1 = df_1[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_1
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-05-01T23:58:57      R      40.0  1.044536  2.5266         2  1.612813
# 1  2019-05-02T00:15:35      R      40.0  1.068864  3.0055         2  1.892192
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-011_R.fit

# %%
df_MAI = df_1
df_MAI.to_csv('seeing_40s_R_MAI.csv')
df_MAI
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-05-01T23:58:57      R      40.0  1.044536  2.5266         2  1.612813
# 1  2019-05-02T00:15:35      R      40.0  1.068864  3.0055         2  1.892192
#
#                   IMAGE-NAME
# 0  1998NU_40s_b2x2-001_R.fit
# 1  1998NU_40s_b2x2-011_R.fit

# %% [markdown]
# <h1>JUNHO</h1>

# %% [markdown]
# <h2>2019-06-04</h2>

# %%
file = open('JUN/2019-06-04/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_4 = pd.read_csv('JUN/2019-06-04/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_4['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_4 = df_4[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_4['XBINNING']*df_4['FWHM']*df_4['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_4['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_4 = df_4[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_4
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-06-05T01:40:46      R      40.0  1.111919  1.9390         2  1.192164
# 1  2019-06-05T02:00:33      R      40.0  1.161883  2.0856         2  1.248922
# 2  2019-06-05T03:00:14      R      40.0  1.411558  2.0746         2  1.105394
# 3  2019-06-05T04:00:10      R      40.0  1.958707  2.3528         2  1.029924
# 4  2019-06-05T04:19:01      R      40.0  2.266804  2.2526         2  0.903312
#
#                 IMAGE-NAME
# 0  1459_40s_b2x2-001_R.fit
# 1  1459_40s_b2x2-029_R.fit
# 2  1459_40s_b2x2-113_R.fit
# 3  1459_40s_b2x2-198_R.fit
# 4  1459_40s_b2x2-225_R.fit

# %% [markdown]
# <h2>2019-06-05</h2>

# %%
file = open('JUN/2019-06-05/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_5 = pd.read_csv('JUN/2019-06-05/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_5['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_5 = df_5[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_5['XBINNING']*df_5['FWHM']*df_5['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_5['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_5 = df_5[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_5
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-06-06T00:58:41      R      40.0  1.047074  2.0746         2  1.322360
# 1  2019-06-06T02:00:11      R      40.0  1.173909  2.7141         2  1.615277
# 2  2019-06-06T03:03:43      R      40.0  1.461206  2.8776         2  1.501777
# 3  2019-06-06T04:00:41      R      40.0  2.031272  3.1207         2  1.336574
# 4  2019-06-06T04:11:11      R      40.0  2.204733  3.3885         2  1.381643
#
#                 IMAGE-NAME
# 0  1459_40s_b2x2-001_R.fit
# 1  1459_40s_b2x2-074_R.fit
# 2  1459_40s_b2x2-149_R.fit
# 3  1459_40s_b2x2-230_R.fit
# 4  1459_40s_b2x2-245_R.fit

# %%
df_JUN = pd.concat([df_4,df_5],sort=False)
df_JUN.to_csv('seeing_40s_R_JUN.csv')
df_JUN
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-06-05T01:40:46      R      40.0  1.111919  1.9390         2  1.192164
# 1  2019-06-05T02:00:33      R      40.0  1.161883  2.0856         2  1.248922
# 2  2019-06-05T03:00:14      R      40.0  1.411558  2.0746         2  1.105394
# 3  2019-06-05T04:00:10      R      40.0  1.958707  2.3528         2  1.029924
# 4  2019-06-05T04:19:01      R      40.0  2.266804  2.2526         2  0.903312
# 0  2019-06-06T00:58:41      R      40.0  1.047074  2.0746         2  1.322360
# 1  2019-06-06T02:00:11      R      40.0  1.173909  2.7141         2  1.615277
# 2  2019-06-06T03:03:43      R      40.0  1.461206  2.8776         2  1.501777
# 3  2019-06-06T04:00:41      R      40.0  2.031272  3.1207         2  1.336574
# 4  2019-06-06T04:11:11      R      40.0  2.204733  3.3885         2  1.381643
#
#                 IMAGE-NAME
# 0  1459_40s_b2x2-001_R.fit
# 1  1459_40s_b2x2-029_R.fit
# 2  1459_40s_b2x2-113_R.fit
# 3  1459_40s_b2x2-198_R.fit
# 4  1459_40s_b2x2-225_R.fit
# 0  1459_40s_b2x2-001_R.fit
# 1  1459_40s_b2x2-074_R.fit
# 2  1459_40s_b2x2-149_R.fit
# 3  1459_40s_b2x2-230_R.fit
# 4  1459_40s_b2x2-245_R.fit

# %% [markdown]
# <h1>AGOSTO</h1>

# %% [markdown]
# <h2>2019-08-27</h2>

# %%
file = open('AGO/2019-08-27/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_27 = pd.read_csv('AGO/2019-08-27/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_27['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_27 = df_27[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_27['XBINNING']*df_27['FWHM']*df_27['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_27['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_27 = df_27[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_27
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-27T23:24:13      R      40.0  1.520295  3.3617         2  1.713184
# 1  2019-08-28T00:00:39      R      40.0  1.318749  3.1311         2  1.737807
# 2  2019-08-28T01:00:10      R      40.0  1.137680  2.7150         2  1.646491
# 3  2019-08-28T02:04:48      R      40.0  1.063107  2.6550         2  1.676950
# 4  2019-08-28T03:00:11      R      40.0  1.071812  3.1903         2  2.005221
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-053_R.fit
# 2  2001RB18_40s_b2x2-138_R.fit
# 3  2001RB18_40s_b2x2-219_R.fit
# 4  2001RB18_40s_b2x2-298_R.fit

# %% [markdown]
# <h2>2019-08-28</h2>

# %%
file = open('AGO/2019-08-28/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_28 = pd.read_csv('AGO/2019-08-28/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_28['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_28 = df_28[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_28['XBINNING']*df_28['FWHM']*df_28['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_28['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_28 = df_28[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_28
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-28T23:39:05      R      40.0  1.423018  2.7065         2  1.435105
# 1  2019-08-29T00:00:18      R      40.0  1.318093  2.2358         2  1.241272
# 2  2019-08-29T01:13:15      R      40.0  1.108266  2.0593         2  1.268630
# 3  2019-08-29T02:25:08      R      40.0  1.061233  3.1063         2  1.964078
# 4  2019-08-29T03:00:06      R      40.0  1.075156  2.4441         2  1.533338
# 5  2019-08-29T04:00:37      R      40.0  1.167274  2.2581         2  1.348470
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-031_R.fit
# 2  2001RB18_40s_b2x2-099_R.fit
# 3  2001RB18_40s_b2x2-145_R.fit
# 4  2001RB18_40s_b2x2-193_R.fit
# 5  2001RB18_40s_b2x2-279_R.fit

# %% [markdown]
# <h2>2019-08-29</h2>

# %%
file = open('AGO/2019-08-29/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_29 = pd.read_csv('AGO/2019-08-29/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_29['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_29 = df_29[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_29['XBINNING']*df_29['FWHM']*df_29['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_29['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_29 = df_29[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_29
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-30T00:27:11      R      40.0  1.219553  2.1463         2  1.248452
# 1  2019-08-30T02:01:36      R      40.0  1.068095  2.1581         2  1.359275
# 2  2019-08-30T03:00:27      R      40.0  1.078871  2.0990         2  1.314112
# 3  2019-08-30T04:00:16      R      40.0  1.171638  2.1287         2  1.268353
# 4  2019-08-30T05:00:19      R      40.0  1.389555  1.8658         2  1.003556
# 5  2019-08-30T06:02:50      R      40.0  1.898295  2.3252         2  1.037156
# 6  2019-08-30T06:35:12      R      40.0  2.439876  2.7884         2  1.069883
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-047_R.fit
# 2  2001RB18_40s_b2x2-130_R.fit
# 3  2001RB18_40s_b2x2-215_R.fit
# 4  2001RB18_40s_b2x2-302_R.fit
# 5  2001RB18_40s_b2x2-375_R.fit
# 6  2001RB18_40s_b2x2-422_R.fit

# %% [markdown]
# <h2>2019-08-30</h2>

# %%
file = open('AGO/2019-08-30/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_30 = pd.read_csv('AGO/2019-08-30/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_30['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_30 = df_30[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_30['XBINNING']*df_30['FWHM']*df_30['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_30['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_30 = df_30[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_30
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-30T23:09:51      R      40.0  1.615629  2.0624         2  1.013374
# 1  2019-08-31T00:00:22      R      40.0  1.315177  2.0837         2  1.158368
# 2  2019-08-31T01:00:36      R      40.0  1.138720  2.5122         2  1.522670
# 3  2019-08-31T01:17:58      R      40.0  1.109933  2.5121         2  1.546182
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-073_R.fit
# 2  2001RB18_40s_b2x2-137_R.fit
# 3  2001RB18_40s_b2x2-159_R.fit

# %% [markdown]
# <h2>2019-08-31</h2>

# %%
file = open('AGO/2019-08-31/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_31 = pd.read_csv('AGO/2019-08-31/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_31['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_31 = df_31[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_31['XBINNING']*df_31['FWHM']*df_31['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_31['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_31 = df_31[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_31
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-31T22:33:15      R      40.0  2.005861  2.1306         2  0.919440
# 1  2019-08-31T23:00:02      R      40.0  1.697341  2.2821         2  1.088617
# 2  2019-09-01T00:00:02      R      40.0  1.315701  3.0621         2  1.701872
# 3  2019-09-01T00:25:42      R      40.0  1.223572  2.6801         2  1.555877
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-039_R.fit
# 2  2001RB18_40s_b2x2-124_R.fit
# 3  2001RB18_40s_b2x2-161_R.fit

# %%
df_AGO = pd.concat([df_27,df_28,df_29,df_30,df_31],sort=False)
df_AGO.to_csv('seeing_40s_R_AGO.csv')
df_AGO
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-08-27T23:24:13      R      40.0  1.520295  3.3617         2  1.713184
# 1  2019-08-28T00:00:39      R      40.0  1.318749  3.1311         2  1.737807
# 2  2019-08-28T01:00:10      R      40.0  1.137680  2.7150         2  1.646491
# 3  2019-08-28T02:04:48      R      40.0  1.063107  2.6550         2  1.676950
# 4  2019-08-28T03:00:11      R      40.0  1.071812  3.1903         2  2.005221
# 0  2019-08-28T23:39:05      R      40.0  1.423018  2.7065         2  1.435105
# 1  2019-08-29T00:00:18      R      40.0  1.318093  2.2358         2  1.241272
# 2  2019-08-29T01:13:15      R      40.0  1.108266  2.0593         2  1.268630
# 3  2019-08-29T02:25:08      R      40.0  1.061233  3.1063         2  1.964078
# 4  2019-08-29T03:00:06      R      40.0  1.075156  2.4441         2  1.533338
# 5  2019-08-29T04:00:37      R      40.0  1.167274  2.2581         2  1.348470
# 0  2019-08-30T00:27:11      R      40.0  1.219553  2.1463         2  1.248452
# 1  2019-08-30T02:01:36      R      40.0  1.068095  2.1581         2  1.359275
# 2  2019-08-30T03:00:27      R      40.0  1.078871  2.0990         2  1.314112
# 3  2019-08-30T04:00:16      R      40.0  1.171638  2.1287         2  1.268353
# 4  2019-08-30T05:00:19      R      40.0  1.389555  1.8658         2  1.003556
# 5  2019-08-30T06:02:50      R      40.0  1.898295  2.3252         2  1.037156
# 6  2019-08-30T06:35:12      R      40.0  2.439876  2.7884         2  1.069883
# 0  2019-08-30T23:09:51      R      40.0  1.615629  2.0624         2  1.013374
# 1  2019-08-31T00:00:22      R      40.0  1.315177  2.0837         2  1.158368
# 2  2019-08-31T01:00:36      R      40.0  1.138720  2.5122         2  1.522670
# 3  2019-08-31T01:17:58      R      40.0  1.109933  2.5121         2  1.546182
# 0  2019-08-31T22:33:15      R      40.0  2.005861  2.1306         2  0.919440
# 1  2019-08-31T23:00:02      R      40.0  1.697341  2.2821         2  1.088617
# 2  2019-09-01T00:00:02      R      40.0  1.315701  3.0621         2  1.701872
# 3  2019-09-01T00:25:42      R      40.0  1.223572  2.6801         2  1.555877
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-053_R.fit
# 2  2001RB18_40s_b2x2-138_R.fit
# 3  2001RB18_40s_b2x2-219_R.fit
# 4  2001RB18_40s_b2x2-298_R.fit
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-031_R.fit
# 2  2001RB18_40s_b2x2-099_R.fit
# 3  2001RB18_40s_b2x2-145_R.fit
# 4  2001RB18_40s_b2x2-193_R.fit
# 5  2001RB18_40s_b2x2-279_R.fit
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-047_R.fit
# 2  2001RB18_40s_b2x2-130_R.fit
# 3  2001RB18_40s_b2x2-215_R.fit
# 4  2001RB18_40s_b2x2-302_R.fit
# 5  2001RB18_40s_b2x2-375_R.fit
# 6  2001RB18_40s_b2x2-422_R.fit
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-073_R.fit
# 2  2001RB18_40s_b2x2-137_R.fit
# 3  2001RB18_40s_b2x2-159_R.fit
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-039_R.fit
# 2  2001RB18_40s_b2x2-124_R.fit
# 3  2001RB18_40s_b2x2-161_R.fit

# %% [markdown]
# <h1>SETEMBRO</h1>

# %% [markdown]
# <h2>2019-09-04</h2>

# %%
file = open('SET/2019-09-04/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_4 = pd.read_csv('SET/2019-09-04/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_4['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_4 = df_4[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_4['XBINNING']*df_4['FWHM']*df_4['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_4['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_4 = df_4[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_4
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-05T00:16:54      R      40.0  1.263460  1.9880         2  1.132091
# 1  2019-09-05T01:00:20      R      40.0  1.150778  2.6691         2  1.607577
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-063_R.fit

# %% [markdown]
# <h2>2019-09-05</h2>

# %%
file = open('SET/2019-09-05/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_5 = pd.read_csv('SET/2019-09-05/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_5['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_5 = df_5[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_5['XBINNING']*df_5['FWHM']*df_5['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_5['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_5 = df_5[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_5
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-06T00:37:47      R      40.0  1.205926  3.2132         2  1.881686
# 1  2019-09-06T01:00:04      R      40.0  1.155686  2.0921         2  1.256841
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-033_R.fit

# %%
df_SET = pd.concat([df_4,df_5],sort=False)
df_SET.to_csv('seeing_40s_R_SET.csv')
df_SET
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-09-05T00:16:54      R      40.0  1.263460  1.9880         2  1.132091
# 1  2019-09-05T01:00:20      R      40.0  1.150778  2.6691         2  1.607577
# 0  2019-09-06T00:37:47      R      40.0  1.205926  3.2132         2  1.881686
# 1  2019-09-06T01:00:04      R      40.0  1.155686  2.0921         2  1.256841
#
#                     IMAGE-NAME
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-063_R.fit
# 0  2001RB18_40s_b2x2-001_R.fit
# 1  2001RB18_40s_b2x2-033_R.fit

# %% [markdown]
# <h1>OUTUBRO</h1>

# %% [markdown]
# <h2>2019-10-25</h2>

# %%
file = open('OUT/2019-10-25/logfile','r')                #Abrindo o arquivo onde estão os valores do fwhm

fwhm = []                                                #Inicializando a lista do fwhm

for indice, linha in enumerate(file):                    #Loop para ler as linhas apartir da 1930 e pegar o fwhm
    if indice  > 1:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm.append(float(linha[39:]))

# %%
#Lendo o arquivo criado pelo hselect no IRAF que contém os dados do header
df_25 = pd.read_csv('OUT/2019-10-25/hselect_40s_R.dat',sep='\t',header=None,names=['DATE-OBS', 
                                                                               'FILTER',
                                                                               'EXP-TIME',
                                                                               'AIRMASS',
                                                                               'XBINNING',
                                                                               'IMAGE-NAME'])

# %%
df_25['FWHM'] = fwhm                                         #Criando uma coluna com os valores do fwhm

df_25 = df_25[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING', 
         'IMAGE-NAME']]                                   #Mudando a ordem das colunas

# %%
'''
- Inicializando lista do seeing
- Calculando o seeing
- Transformando o primeiro elemento da lista (que contém todos os valores do seeing) em uma lista
'''
seeing = []
seeing.append(0.343*df_25['XBINNING']*df_25['FWHM']*df_25['AIRMASS']**(-0.6)*(6289/5000)**(-0.2))
seeing = seeing[0].values.tolist()

# %%
df_25['SEEING'] = seeing                                        #Criando uma coluna com os valores do seeing

df_25 = df_25[['DATE-OBS', 
         'FILTER',
         'EXP-TIME',
         'AIRMASS',
         'FWHM',
         'XBINNING',
         'SEEING',
         'IMAGE-NAME']]                                      #Mudando a ordem das colunas
df_25
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-10-26T01:42:29      R      40.0  1.372531  3.9620         2  2.146856
# 1  2019-10-26T02:41:52      R      40.0  1.334847  4.3686         2  2.407050
#
#                     IMAGE-NAME
# 0  2011MD11_40s_b2x2-001_R.fit
# 1  2011MD11_40s_b2x2-042_R.fit

# %%
df_OUT = df_25
df_OUT.to_csv('seeing_40s_R_OUT.csv')
df_OUT
# Out:
#               DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING    SEEING  \
# 0  2019-10-26T01:42:29      R      40.0  1.372531  3.9620         2  2.146856
# 1  2019-10-26T02:41:52      R      40.0  1.334847  4.3686         2  2.407050
#
#                     IMAGE-NAME
# 0  2011MD11_40s_b2x2-001_R.fit
# 1  2011MD11_40s_b2x2-042_R.fit

# %% [markdown]
# <h1>Seeing x Tempo </h1>

# %%
df_2019 = pd.concat([df_JAN,df_FEV,df_MAR,df_ABR,df_MAI,df_JUN,df_AGO,df_SET,df_OUT],sort=False)
df_2019.to_csv('seeing_40s.csv')
df_2019
# Out:
#                DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING  \
# 0   2019-01-08T23:11:50      R      40.0  2.436941  1.9656         2
# 1   2019-01-09T00:00:41      R      40.0  1.769175  1.8695         2
# 2   2019-01-09T01:00:31      R      40.0  1.396026  2.1602         2
# 3   2019-01-09T02:00:28      R      40.0  1.226796  1.9850         2
# 4   2019-01-09T03:00:21      R      40.0  1.170334  1.7584         2
# ..                  ...    ...       ...       ...     ...       ...
# 1   2019-09-05T01:00:20      R      40.0  1.150778  2.6691         2
# 0   2019-09-06T00:37:47      R      40.0  1.205926  3.2132         2
# 1   2019-09-06T01:00:04      R      40.0  1.155686  2.0921         2
# 0   2019-10-26T01:42:29      R      40.0  1.372531  3.9620         2
# 1   2019-10-26T02:41:52      R      40.0  1.334847  4.3686         2
#
#       SEEING                   IMAGE-NAME
# 0   0.754727    1998NU_40s_b2x2-001_R.fit
# 1   0.869891    1998NU_40s_b2x2-070_R.fit
# 2   1.158670    1998NU_40s_b2x2-155_R.fit
# 3   1.150532    1998NU_40s_b2x2-240_R.fit
# 4   1.048416    1998NU_40s_b2x2-324_R.fit
# ..       ...                          ...
# 1   1.607577  2001RB18_40s_b2x2-063_R.fit
# 0   1.881686  2001RB18_40s_b2x2-001_R.fit
# 1   1.256841  2001RB18_40s_b2x2-033_R.fit
# 0   2.146856  2011MD11_40s_b2x2-001_R.fit
# 1   2.407050  2011MD11_40s_b2x2-042_R.fit
#
# [106 rows x 8 columns]

# %%
df_2019['SEEING'].max()
# Out:
# 3.3875295151053857

# %%
lista_tempos = Time(list(df_2019['DATE-OBS']),format='isot',scale='utc')

dt = []
t = np.empty(len(df_2019['DATE-OBS']))

for i in range(len(lista_tempos)):
    dt.append(lista_tempos[i] - itime)
    t[i] = (dt[i].value)/30

# %%
len(t)
# Out:
# 106

# %%
estat = pd.DataFrame({'MÉDIA':[std.mean(df_2019['SEEING'])],'MEDIANA':[std.median(df_2019['SEEING'])],'MODA':[''],'DESVPAD':[std.stdev(df_2019['SEEING'])]})
estat.to_csv('estat_R_40s.dat')
estat
#std.multimode(df_2019['SEEING'])
# Out:
#       MÉDIA  MEDIANA MODA   DESVPAD
# 0  1.366482  1.27329       0.474234

# %%
'''
Modas calculadas com o comando std.multimode() no pyhton3.8, rodado no terminal
'''

plt.figure(figsize=(9,7))
plt.hist(list(df_2019['SEEING']),bins = 50,label = 'Filtro R\n Tempo de exposição = 40s',color = 'blue',alpha = 0.5,lw = 1,edgecolor = 'black')
plt.ylabel('Frquência das imagens',size = 15)
plt.xlabel('Seeing (")',size = 15)
plt.xticks(np.arange(0,5,0.5),size = 15)
plt.yticks(np.arange(0,13,2),size = 15)
#plt.title('Seeing (1.48 $\pm$ 0.55) arcsec' + '      mediana 1.29 arcsec',size = 12,color='black')
plt.title('Média = 1.36 arcsec  Mediana = 1.27 arcsec  Moda = 1.35 arcsec  $\sigma$ = 0.47 arcsec',size = 11.5)
plt.legend(prop={'size': 10},frameon = True,loc = 'upper right', fancybox = True, framealpha = 1, shadow = True, borderpad = 0.5 )
plt.savefig('seeing_40s.png')
plt.show()

# %%
seeing_15 = df_2019[(df_2019.SEEING < 1.5)]
seeing_15
# Out:
#                DATE-OBS FILTER  EXP-TIME   AIRMASS    FWHM  XBINNING  \
# 0   2019-01-08T23:11:50      R      40.0  2.436941  1.9656         2
# 1   2019-01-09T00:00:41      R      40.0  1.769175  1.8695         2
# 2   2019-01-09T01:00:31      R      40.0  1.396026  2.1602         2
# 3   2019-01-09T02:00:28      R      40.0  1.226796  1.9850         2
# 4   2019-01-09T03:00:21      R      40.0  1.170334  1.7584         2
# ..                  ...    ...       ...       ...     ...       ...
# 1   2019-08-31T00:00:22      R      40.0  1.315177  2.0837         2
# 0   2019-08-31T22:33:15      R      40.0  2.005861  2.1306         2
# 1   2019-08-31T23:00:02      R      40.0  1.697341  2.2821         2
# 0   2019-09-05T00:16:54      R      40.0  1.263460  1.9880         2
# 1   2019-09-06T01:00:04      R      40.0  1.155686  2.0921         2
#
#       SEEING                   IMAGE-NAME
# 0   0.754727    1998NU_40s_b2x2-001_R.fit
# 1   0.869891    1998NU_40s_b2x2-070_R.fit
# 2   1.158670    1998NU_40s_b2x2-155_R.fit
# 3   1.150532    1998NU_40s_b2x2-240_R.fit
# 4   1.048416    1998NU_40s_b2x2-324_R.fit
# ..       ...                          ...
# 1   1.158368  2001RB18_40s_b2x2-073_R.fit
# 0   0.919440  2001RB18_40s_b2x2-001_R.fit
# 1   1.088617  2001RB18_40s_b2x2-039_R.fit
# 0   1.132091  2001RB18_40s_b2x2-001_R.fit
# 1   1.256841  2001RB18_40s_b2x2-033_R.fit
#
# [76 rows x 8 columns]

# %%
len(seeing_15)
# Out:
# 76

# %%
it = ['2019-01-01T21:00:00']                             #Inicio das observaçoes
itime = Time(it, format = 'isot', scale = 'utc' )

# %%
lista_tempos = Time(list(seeing_15['DATE-OBS']),format='isot',scale='utc')

dt = []
t = np.empty(len(seeing_15['DATE-OBS']))

for i in range(len(lista_tempos)):
    dt.append(lista_tempos[i] - itime)
    t[i] = (dt[i].value)/30

# %%
len(t) == len(seeing_15['SEEING'])
# Out:
# True

# %%
plt.figure(figsize=(9,7))
plt.scatter(t,seeing_15['SEEING'], label = 'Filtro R\nTempo de exposição = 40s', alpha = 1,lw = 0.8, edgecolor = 'black')
plt.xticks(np.arange(13),('Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez'), rotation = 45, size = 15)
plt.yticks(np.arange(1,2,0.5))
plt.xlim(0,12)
plt.xlabel('Tempo de observação',size = 15)
plt.ylabel('Seeing (")',size = 15)
plt.legend(prop={'size': 10},frameon = True,loc = 'upper right', fancybox = True, framealpha = 1, shadow = True, borderpad = 0.5 )
plt.savefig('seeingxtempo_40s.png')
plt.show()
