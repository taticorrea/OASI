# %%
# %matplotlib inline
import statistics as std
import pandas as pd                                 
import numpy as np                          #Importando os módulos necessários
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.time import Time
from astropy.io.fits import HDUList

# %%
file = open('logfile','r')                       #Abrindo o arquivo com os dados
fwhm_A10BMLZ = []
fwhm_1998OH = []                                 #Listas vazias para salvar os valores do fwhm
fwhm_2003CP20 = []
fwhm_2003YE45 = []                          


#A10BMLZ
for indice, linha in enumerate(file):            #Loop para ler as linhas apartir da 1
    if indice < 221 :
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm_A10BMLZ.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm_A10BMLZ.append(float(linha[39:]))
#1998OH  
    elif indice > 222 and indice < 267:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm_1998OH.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm_1998OH.append(float(linha[39:]))
#2003CP20
    if indice > 268 and indice < 387 :
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm_2003CP20.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm_2003CP20.append(float(linha[39:]))
#2003YE45
    elif indice > 388:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm_2003YE45.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm_2003YE45.append(float(linha[39:]))


fwhm_A10BMLZ = sorted(fwhm_A10BMLZ)            
fwhm_1998OH = sorted(fwhm_1998OH)
fwhm_2003CP20 = sorted(fwhm_2003CP20)
fwhm_2003YE45 = sorted(fwhm_2003YE45)

# %% [markdown]
# <h1>A10BMLZ</h1>

# %%
#imagens usadas no psfmeasure = 10/20/30/40/50/60/70

name_A10BMLZ = 'A10BMLZ/A10BMLZ_10s_b2x2-010_SF.fit'
imagens_A10BMLZ = []                                                        #Lista com o nome das imagens

for i in range(0,70,10):
    number_A10BMLZ = name_A10BMLZ[25:28].replace(name_A10BMLZ[26:28],str(int(name_A10BMLZ[26:28])+i))
    imagens_A10BMLZ.append('A10BMLZ/A10BMLZ_10s_b2x2-' + str(number_A10BMLZ) + '_SF.fit' )

# %%
date_obs_A10BMLZ = []                                                #Lista com as datas

for i in imagens_A10BMLZ:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            date_obs_A10BMLZ.append(hdul[0].header['DATE-OBS'])

filtro_A10BMLZ = []                                                #Lista com as datas

for i in imagens_A10BMLZ:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            filtro_A10BMLZ.append(hdul[0].header['FILTER'])

exp_time_A10BMLZ = []                                                #Lista com as datas

for i in imagens_A10BMLZ:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            exp_time_A10BMLZ.append(hdul[0].header['EXPTIME'])

airmass_A10BMLZ = []                                                #Lista com as datas

for i in imagens_A10BMLZ:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            airmass_A10BMLZ.append(hdul[0].header['AIRMASS'])

# %%
d_A10BMLZ = {'DATE-OBS':date_obs_A10BMLZ,'EXP-TIME':exp_time_A10BMLZ,'AIRMASS':airmass_A10BMLZ,'FILTER':filtro_A10BMLZ,'FWHM':fwhm_A10BMLZ,'NAME':imagens_A10BMLZ}
df_A10BMLZ = pd.DataFrame(data=d_A10BMLZ)
df_A10BMLZ = df_A10BMLZ.sort_values(by='DATE-OBS')

# %% [markdown]
# <h1>1998OH</h1>

# %%
#imagens usadas no psfmeasure = 10/20/30/40/50/
name_1998OH = '1998OH/1998NU_90s_b2x2-010_R.fit'
imagens_1998OH = []                                                        #Lista com o nome das imagens

for i in range(0,50,10):       
    number_1998OH = name_1998OH[23:26].replace(name_1998OH[24:26],str(int(name_1998OH[24:26])+i))
    imagens_1998OH.append('1998OH/1998OH_90s_b2x2-' + str(number_1998OH) + '_R.fit' )

# %%
date_obs_1998OH = []                                                #Lista com as datas

for i in imagens_1998OH:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            date_obs_1998OH.append(hdul[0].header['DATE-OBS'])

filtro_1998OH = []                                                #Lista com as datas

for i in imagens_1998OH:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            filtro_1998OH.append(hdul[0].header['FILTER'])

exp_time_1998OH = []                                                #Lista com as datas

for i in imagens_1998OH:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            exp_time_1998OH.append(hdul[0].header['EXPTIME'])

airmass_1998OH = []                                                #Lista com as datas

for i in imagens_1998OH:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            airmass_1998OH.append(hdul[0].header['AIRMASS'])

# %%
d_1998OH = {'DATE-OBS':date_obs_1998OH,'EXP-TIME':exp_time_1998OH,'AIRMASS':airmass_1998OH,'FILTER':filtro_1998OH,'FWHM':fwhm_1998OH,'NAME':imagens_1998OH}
df_1998OH= pd.DataFrame(data=d_1998OH)
df_1998OH = df_1998OH.sort_values(by='DATE-OBS')

# %% [markdown]
# <h1>2003CP20</h1>

# %%
#imagens usadas no psfmeasure = 5/10/15/20/25

name_2003CP20 = '2003CP20/2003CP20_90s_b2x2-010_R.fit'
imagens_2003CP20 = []                                                        #Lista com o nome das imagens

for i in range(0,20,5):       
        number_2003CP20 = name_2003CP20[27:30].replace(name_2003CP20[28:30],str(int(name_2003CP20[28:30])+i))   
        imagens_2003CP20.append('2003CP20/2003CP20_90s_b2x2-' + str(number_2003CP20) + '_R.fit' )

imagens_2003CP20.insert(0,'2003CP20/2003CP20_90s_b2x2-005_R.fit')

# %%
date_obs_2003CP20 = []                                                #Lista com as datas

for i in imagens_2003CP20:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            date_obs_2003CP20.append(hdul[0].header['DATE-OBS'])

filtro_2003CP20 = []                                                #Lista com as datas

for i in imagens_2003CP20:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            filtro_2003CP20.append(hdul[0].header['FILTER'])

exp_time_2003CP20 = []                                                #Lista com as datas

for i in imagens_2003CP20:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            exp_time_2003CP20.append(hdul[0].header['EXPTIME'])

airmass_2003CP20 = []                                                #Lista com as datas

for i in imagens_2003CP20:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            airmass_2003CP20.append(hdul[0].header['AIRMASS'])

# %%
d_2003CP20 = {'DATE-OBS':date_obs_2003CP20,'EXP-TIME':exp_time_2003CP20,'AIRMASS':airmass_2003CP20,'FILTER':filtro_2003CP20,'FWHM':fwhm_2003CP20,'NAME':imagens_2003CP20}
df_2003CP20 = pd.DataFrame(data=d_2003CP20)
df_2003CP20 = df_2003CP20.sort_values(by='DATE-OBS')

# %% [markdown]
# <h1>2003YE45</h1>

# %%
#imagens usadas no psfmeasure = 5/10/15/20/25/30/35/40

name_2003YE45 = '2003YE45/2003YE45_90s_b2x2-010_R.fit'
imagens_2003YE45 = []                                                         #Lista com o nome das imagens

for i in range(0,35,5):       
    number_2003YE45 = name_2003YE45[27:30].replace(name_2003YE45[28:30],str(int(name_2003YE45[28:30])+i))   
    imagens_2003YE45.append('2003YE45/2003YE45_90s_b2x2-' + str(number_2003YE45) + '_R.fit' )
        
imagens_2003YE45.insert(0,'2003YE45/2003YE45_90s_b2x2-005_R.fit')

# %%
date_obs_2003YE45 = []                                                #Lista com as datas

for i in imagens_2003YE45:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            date_obs_2003YE45.append(hdul[0].header['DATE-OBS'])

filtro_2003YE45 = []                                                #Lista com as datas

for i in imagens_2003YE45:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            filtro_2003YE45.append(hdul[0].header['FILTER'])

exp_time_2003YE45 = []                                                #Lista com as datas

for i in imagens_2003YE45:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            exp_time_2003YE45.append(hdul[0].header['EXPTIME'])

airmass_2003YE45 = []                                                #Lista com as datas

for i in imagens_2003YE45:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            airmass_2003YE45.append(hdul[0].header['AIRMASS'])

# %%
d_2003YE45 = {'DATE-OBS':date_obs_2003YE45,'EXP-TIME':exp_time_2003YE45,'AIRMASS':airmass_2003YE45,'FILTER':filtro_2003YE45,'FWHM':fwhm_2003YE45,'NAME':imagens_2003YE45}
df_2003YE45 = pd.DataFrame(data=d_2003YE45)
df_2003YE45 = df_2003YE45.sort_values(by='DATE-OBS')

# %%
df = pd.concat([df_1998OH,df_2003YE45,df_A10BMLZ,df_2003CP20], ignore_index=True)
