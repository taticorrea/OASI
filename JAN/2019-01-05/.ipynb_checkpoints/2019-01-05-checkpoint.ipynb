# %% [markdown]
# <h1>2019-01-05</h1>

# %% [markdown]
# <h2>2002LJ3</h2>

# %%
# %matplotlib inline
import statistics as std
import pandas as pd                                 
import numpy as np                                         #Importando os módulos necessários
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.time import Time

# %% [markdown]
# <h3>Raw data</h3>

# %%
rfile = open('JAN/2019-01-05/2002LJ3_2019-01-05_dados_brutos.csv','r')                #Abrindo o arquivo com os dados
rdF = pd.read_csv(rfile)                                   #Lendo e salvando os dados na variável dF

rdados = list(rdF['DATE-OBS'])                             #Transformando a coluna DATE-OBS em uma lista
rfwhm = list(rdF['FWHM'])                                  #Transformando a coluna FWHM em uma lista

rtimes = Time(rdados, format = 'isot', scale = 'utc')      #Instanciando a classe Time com os dados

it = ['2019-01-05T21:00:00']
itime = Time(it, format = 'isot', scale = 'utc' )

rfwhmm = np.empty(len(rfwhm))                              #Iniciando array vazio com tamanho da coluna fwhm
rdt = []                                                   #Inicializando a lista com os pontos
rt = np.empty(len(rdados))                                 #Inicializando array para plotar

for i in range(len(rfwhm)):
    rfwhmm[i] = rfwhm[i].replace(',','.')                  #Tirando o ',' e colocar '.' para decimal
    rdt.append(rtimes[i] - itime)
    rt[i] = (rdt[i].value)*24                              #Calculando os valores de dt em HORAS

rFWHM = list(rfwhmm)                                       #Lista FWHM

# %% [markdown]
# <h3>Calibrated data</h3>

# %%
cfile = open('JAN/2019-01-05/2002LJ3_2019-01-05_dados_calibrados.csv','r')                #Abrindo o arquivo com os dados
cdF = pd.read_csv(cfile)                                   #Lendo e salvando os dados na variável dF

cdados = list(cdF['DATE-OBS'])                             #Transformando a coluna DATE-OBS em uma lista
cfwhm = list(cdF['FWHM'])                                  #Transformando a coluna FWHM em uma lista

ctimes = Time(cdados, format = 'isot', scale = 'utc')      #Instanciando a classe Time com os dados

it = ['2019-01-05T21:00:00']
itime = Time(it, format = 'isot', scale = 'utc' )

cfwhmm = np.empty(len(cfwhm))                              #Iniciando array vazio com tamanho da coluna fwhm
cdt = []                                                   #Inicializando a lista com os pontos
ct = np.empty(len(cdados))                                 #Inicializando array para plotar

for i in range(len(cfwhm)):
    cfwhmm[i] = cfwhm[i].replace(',','.')                  #Tirando o ',' e colocar '.' para decimal
    cdt.append(ctimes[i] - itime)
    ct[i] = (cdt[i].value)*24                              #Calculando os valores de dt em HORAS

cFWHM = list(cfwhmm)                                       #Convertendo fwhm em lista

# %%
plt.figure(figsize=(9,7))
plt.plot(ct, cFWHM, color = 'blue', label = 'calibrated data')              #Calibrated
plt.plot(rt, rFWHM, color = 'green', label = 'raw data')                    #Raw
plt.scatter(ct, cFWHM, color = 'blue')                                      #Calibrated
plt.scatter(rt, rFWHM, color = 'green')                                     #Raw
plt.yticks(np.arange(2, 5, 1)) 
plt.xticks(np.arange(0,7,1))                                                #Raw
plt.title('2019-01-05 Filtro R 80s')
plt.ylabel('Fwhm')
plt.xlabel('Time (hours)')
plt.savefig('fwhmxtime.png')
plt.legend()
plt.show()

# %% [markdown]
# <h2>2009SV17</h2>

# %% [markdown]
# <h3>Raw data</h3>

# %%
file = open('JAN/2019-01-05/logfile','r')                       #Abrindo o arquivo com os dados
r1fwhm = []                                       #Lista vazia para salvar os valores do fwhm

for indice, linha in enumerate(file):            #Loop para ler as linhas apartir da 480 e pegar o fwhm
    if indice  > 480 and indice < 616:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            r1fwhm.append(float(linha[47:]))  

rimage1 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-001_R.fit')
rimage2 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-002_R.fit')
rimage3 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-003_R.fit')
rimage4 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-004_R.fit')
rimage5 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-005_R.fit')
rimage6 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-006_R.fit')  #Abrindo as imagens (deve ter um outro jeito!)
rimage7 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-007_R.fit')
rimage8 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-008_R.fit')
rimage9 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-009_R.fit')
rimage10 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-010_R.fit')
rimage11 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-011_R.fit')
rimage12 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-012_R.fit')
rimage13 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-013_R.fit')

r1dados = []

r1dados.append(rimage1[0].header['DATE-OBS'])
r1dados.append(rimage2[0].header['DATE-OBS'])
r1dados.append(rimage3[0].header['DATE-OBS'])
r1dados.append(rimage4[0].header['DATE-OBS'])
r1dados.append(rimage5[0].header['DATE-OBS'])
r1dados.append(rimage6[0].header['DATE-OBS'])     #Salvandoos as datas na lista (deve ter um outro jeito!)
r1dados.append(rimage7[0].header['DATE-OBS'])
r1dados.append(rimage8[0].header['DATE-OBS'])
r1dados.append(rimage9[0].header['DATE-OBS'])
r1dados.append(rimage10[0].header['DATE-OBS'])
r1dados.append(rimage11[0].header['DATE-OBS'])
r1dados.append(rimage12[0].header['DATE-OBS'])
r1dados.append(rimage13[0].header['DATE-OBS'])

r1times = Time(r1dados, format = 'isot', scale = 'utc')      #Instanciando a classe Time com os dados

it = ['2019-01-05T21:00:00']
itime = Time(it, format = 'isot', scale = 'utc' )

r1dt = []                                                   #Inicializando a lista com os pontos
r1t = np.empty(len(r1dados))                                 #Inicializando array para plotar

for i in range(len(r1dados)):
    r1dt.append(r1times[i] - itime)
    r1t[i] = (r1dt[i].value)*24                              #Calculando os valores de dt em HORAS

# %% [markdown]
# <h3>Calibrated data</h3>

# %%
file = open('JAN/2019-01-05/logfile','r')                       #Abrindo o arquivo com os dados
c1fwhm = []                                       #Lista vazia para salvar os valores do fwhm

for indice, linha in enumerate(file):            #Loop para ler as linhas apartir da 480 e pegar o fwhm
    if indice  > 616:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            c1fwhm.append(float(linha[47:]))  

cimage1 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-001_R_c.fit')
cimage2 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-002_R_c.fit')
cimage3 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-003_R_c.fit')
cimage4 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-004_R_c.fit')
cimage5 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-005_R_c.fit')
cimage6 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-006_R_c.fit')  #Abrindo as imagens (deve ter um outro jeito!)
cimage7 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-007_R_c.fit')
cimage8 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-008_R_c.fit')
cimage9 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-009_R_c.fit')
cimage10 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-010_R_c.fit')
cimage11 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-011_R_c.fit')
cimage12 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-012_R_c.fit')
cimage13 = fits.open('JAN/2019-01-05/2009SV17_80s_b2x2-013_R_c.fit')

c1dados = []

c1dados.append(cimage1[0].header['DATE-OBS'])
c1dados.append(cimage2[0].header['DATE-OBS'])
c1dados.append(cimage3[0].header['DATE-OBS'])
c1dados.append(cimage4[0].header['DATE-OBS'])
c1dados.append(cimage5[0].header['DATE-OBS'])
c1dados.append(cimage6[0].header['DATE-OBS'])     #Salvandoos as datas na lista (deve ter um outro jeito!)
c1dados.append(cimage7[0].header['DATE-OBS'])
c1dados.append(cimage8[0].header['DATE-OBS'])
c1dados.append(cimage9[0].header['DATE-OBS'])
c1dados.append(cimage10[0].header['DATE-OBS'])
c1dados.append(cimage11[0].header['DATE-OBS'])
c1dados.append(cimage12[0].header['DATE-OBS'])
c1dados.append(cimage13[0].header['DATE-OBS'])

c1times = Time(c1dados, format = 'isot', scale = 'utc')      #Instanciando a classe Time com os dados

it = ['2019-01-05T21:00:00']
itime = Time(it, format = 'isot', scale = 'utc' )

c1dt = []                                                   #Inicializando a lista com os pontos
c1t = np.empty(len(c1dados))                                 #Inicializando array para plotar

for i in range(len(c1dados)):
    c1dt.append(c1times[i] - itime)
    c1t[i] = (c1dt[i].value)*24                              #Calculando os valores de dt em HORAS

# %%
plt.figure(figsize=(9,7))
plt.scatter(c1t, c1fwhm, color = 'grey', label = 'calibrated data')          #Calibrated
plt.scatter(r1t, r1fwhm, color = 'red', label  ='raw data')                  #Raw
plt.plot(r1t, r1fwhm, color = 'red')                                         #Raw
plt.plot(c1t, c1fwhm, color = 'grey')                                        #Calibrated
plt.title('2019-01-05 Filtro R 80s')
plt.ylabel('Fwhm')
plt.xlabel('Time (hours)')
plt.yticks(np.arange(2.5, 5, 1)) 
plt.savefig('fwhmxtime.png')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,7))
#2002LJ3
#plt.plot(ct, cFWHM, color = 'blue', label = 'calibrated data')              #Calibrated
#plt.plot(rt, rFWHM, color = 'green', label = 'raw data')                    #Raw
plt.scatter(ct, cFWHM, color = 'blue', label = 'Dados calibrados (2002LJ3)')          #Calibrated
plt.scatter(rt, rFWHM, color = 'green', label  ='Dados calibrados (2002LJ3)')                #Raw

#2009SV17
plt.scatter(c1t, c1fwhm, color = 'grey', label  ='Dados calibrados (2009SV17)')         #Calibrated
plt.scatter(r1t, r1fwhm, color = 'red', label  ='Dados brutos (2009SV17)')                 #Raw
#plt.plot(c1t, c1fwhm, color = 'grey')                                            #Calibrated
#plt.plot(r1t, r1fwhm, color = 'red')                                            #Raw


plt.title('2019-01-05 Filtro R 80s')
plt.ylabel('Fwhm')
plt.xlabel('Tempo (horas)')
plt.yticks(np.arange(2, 5, 1)) 
plt.xticks(np.arange(0,11, 1)) 
plt.savefig('fwhmxtime.png')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,7))

#2002LJ3
plt.plot(ct, cFWHM, color = 'blue', label = 'Dados calibrados')      #Calibrated
plt.plot(rt, rFWHM, color = 'green', label = 'Dados brutos')            #Raw

#2009SV17
plt.plot(c1t, c1fwhm, color = 'blue')    #Calibrated
plt.plot(r1t, r1fwhm, color = 'green')            #Raw


#plt.title('2019-01-05 80s - filtro R' , size=10 )
plt.ylabel('FWHM', size = 15)
plt.xlabel('Tempo após 2019-01-05T21:00:00 (horas)', size = 15)
plt.yticks(np.arange(2, 5, 1)) 
plt.xticks(np.arange(0,11, 1)) 
plt.legend()
plt.savefig('fwhmxtime.png')
plt.show()

# %%
RFWHM = rFWHM 

mean_fwhm = std.mean(RFWHM)
median_fwhm = std.median(RFWHM)

print(mean_fwhm)
print(median_fwhm)
