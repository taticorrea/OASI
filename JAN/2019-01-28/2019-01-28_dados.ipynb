# %%
# %matplotlib inline
import statistics as std
import pandas as pd                                 
import numpy as np                          #Importando os módulos necessários
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.time import Time
from astropy.io.fits import HDUList

# %%
file = open('logfile','r')                       #Abrindo o arquivo com os dados
fwhm_HIP41296 = []
fwhm_HIP41621 = []                                 #Listas vazias para salvar os valores do fwhm

#HIP41296
for indice, linha in enumerate(file):            #Loop para ler as linhas apartir da 1
    if indice < 57 :
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm_HIP41296.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm_HIP41296.append(float(linha[39:]))
#HIP41621  
    elif indice > 57:
        if linha[:47] == '  Average full width at half maximum (FWHM) of ': 
            fwhm_HIP41621.append(float(linha[47:]))
        elif linha[:39] == '  Full width at half maximum (FWHM) of ': 
            fwhm_HIP41621.append(float(linha[39:]))

fwhm_HIP41296 = sorted(fwhm_HIP41296)            
fwhm_HIP41621 = sorted(fwhm_HIP41621)

# %% [markdown]
# <h1>HIP41296</h1>

# %%
#imagens usadas no psfmeasure = 10,20,30,40,50,60,70,80

name_HIP41296 = 'HIP41296/HIP41296_b1x1-010_R.fit'
imagens_HIP41296 = []                                                        #Lista com o nome das imagens

for i in range(0,80,10):
    number_HIP41296 = name_HIP41296[23:26].replace(name_HIP41296[24:26],str(int(name_HIP41296[24:26])+i))
    imagens_HIP41296.append('HIP41296/HIP41296_b1x1-' + str(number_HIP41296) + '_R.fit' )

# %%
date_obs_HIP41296 = []                                                #Lista com as datas

for i in imagens_HIP41296:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            date_obs_HIP41296.append(hdul[0].header['DATE-OBS'])

filtro_HIP41296 = []                                                #Lista com as datas

for i in imagens_HIP41296:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            filtro_HIP41296.append(hdul[0].header['FILTER'])

exp_time_HIP41296 = []                                                #Lista com as datas

for i in imagens_HIP41296:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            exp_time_HIP41296.append(hdul[0].header['EXPTIME'])

airmass_HIP41296= []                                                #Lista com as datas

for i in imagens_HIP41296:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            airmass_HIP41296.append(hdul[0].header['AIRMASS'])

# %%
d_HIP41296 = {'DATE-OBS':date_obs_HIP41296,'EXP-TIME':exp_time_HIP41296,'AIRMASS':airmass_HIP41296,'FILTER':filtro_HIP41296,'FWHM':fwhm_HIP41296,'NAME':imagens_HIP41296}
df_HIP41296= pd.DataFrame(data=d_HIP41296)
df_HIP41296 = df_HIP41296.sort_values(by='DATE-OBS')

# %% [markdown]
# <h1>HIP41621</h1>

# %%
#imagens usadas no psfmeasure = 10,20,30,40,50,60
name_HIP41621 = 'HIP41621/HIP41621_b1x1-010_R.fit'
imagens_HIP41621 = []                                                        #Lista com o nome das imagens

for i in range(0,60,10):       
    number_HIP41621 = name_HIP41621[23:26].replace(name_HIP41621[24:26],str(int(name_HIP41621[24:26])+i))
    imagens_HIP41621.append('HIP41621/HIP41621_b1x1-' + str(number_HIP41621) + '_R.fit' )

# %%
date_obs_HIP41621 = []                                                #Lista com as datas

for i in imagens_HIP41621:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            date_obs_HIP41621.append(hdul[0].header['DATE-OBS'])

filtro_HIP41621 = []                                                #Lista com as datas

for i in imagens_HIP41621:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            filtro_HIP41621.append(hdul[0].header['FILTER'])

exp_time_HIP41621 = []                                                #Lista com as datas

for i in imagens_HIP41621:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            exp_time_HIP41621.append(hdul[0].header['EXPTIME'])

airmass_HIP41621 = []                                                #Lista com as datas

for i in imagens_HIP41621:                                        #Iterando dentro da lista com os nomes
    with fits.open(i) as hdul:                           #Abrindo cada elemento da lista imagens
        for hdu in hdul:                                 #Extraindo o header de cada imagem
            airmass_HIP41621.append(hdul[0].header['AIRMASS'])

# %%
d_HIP41621 = {'DATE-OBS':date_obs_HIP41621,'EXP-TIME':exp_time_HIP41621,'AIRMASS':airmass_HIP41621,'FILTER':filtro_HIP41621,'FWHM':fwhm_HIP41621,'NAME':imagens_HIP41621}
df_HIP41621 = pd.DataFrame(data=d_HIP41621)
df_HIP41621 = df_HIP41621.sort_values(by='DATE-OBS')

# %%
df = pd.concat([df_HIP41621,df_HIP41296], ignore_index=True)
df = df.sort_values(by='DATE-OBS')
df.to_csv('2019-01-28_dados.csv')
df
# Out:
#                DATE-OBS  EXP-TIME   AIRMASS FILTER    FWHM  \
# 0   2019-01-29T01:00:54      0.10  1.316226      R  3.1463
# 1   2019-01-29T01:11:59      0.10  1.294837      R  3.2201
# 2   2019-01-29T01:23:04      0.10  1.276669      R  3.8961
# 3   2019-01-29T01:34:05      0.10  1.261604      R  4.4076
# 4   2019-01-29T01:45:09      0.10  1.249308      R  4.4562
# 5   2019-01-29T01:56:16      0.10  1.239690      R  4.7403
# 6   2019-01-29T03:46:46      0.05  1.434725      R  1.5070
# 7   2019-01-29T03:57:55      0.05  1.456968      R  2.8763
# 8   2019-01-29T04:09:03      0.05  1.482806      R  3.3361
# 9   2019-01-29T04:20:14      0.05  1.512702      R  3.5106
# 10  2019-01-29T04:31:27      0.05  1.547004      R  3.7661
# 11  2019-01-29T04:42:40      0.05  1.586054      R  4.2358
# 12  2019-01-29T04:53:52      0.05  1.630287      R  4.6554
# 13  2019-01-29T05:05:04      0.05  1.680361      R  6.9020
#
#                                 NAME
# 0   HIP41621/HIP41621_b1x1-010_R.fit
# 1   HIP41621/HIP41621_b1x1-020_R.fit
# 2   HIP41621/HIP41621_b1x1-030_R.fit
# 3   HIP41621/HIP41621_b1x1-040_R.fit
# 4   HIP41621/HIP41621_b1x1-050_R.fit
# 5   HIP41621/HIP41621_b1x1-060_R.fit
# 6   HIP41296/HIP41296_b1x1-010_R.fit
# 7   HIP41296/HIP41296_b1x1-020_R.fit
# 8   HIP41296/HIP41296_b1x1-030_R.fit
# 9   HIP41296/HIP41296_b1x1-040_R.fit
# 10  HIP41296/HIP41296_b1x1-050_R.fit
# 11  HIP41296/HIP41296_b1x1-060_R.fit
# 12  HIP41296/HIP41296_b1x1-070_R.fit
# 13  HIP41296/HIP41296_b1x1-080_R.fit
